# %% [markdown]
# # QF 627 Programming and Computational Finance
# ## Problem-Sets for Exercise 1 | `Questions`

# %% [markdown]
# > For your further exercise, let's analyze a dataset about [TED talks](https://www.ted.com/talks) using `pandas` and `matplotlib` libraries.

# %% [markdown]
# ### <font color = green> Activation of necessary libraries. </font>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### <font color = "blue"> `IMPORT` your dataset: `ted.csv`. </font>

# %%
df = pd.read_csv('Data/ted.csv')

# %% [markdown]
# > #### Print the imported dataframe. Each row (data points) represents a single talk (unit of observation).

# %%
df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event   film_date  languages         main_speaker  \
# 0          TED2006  1140825600         60         Ken Robinson
# 1          TED2006  1140825600         43              Al Gore
# 2          TED2006  1140739200         26          David Pogue
# 3          TED2006  1140912000         35        Majora Carter
# 4          TED2006  1140566400         48         Hans Rosling
# ...            ...         ...        ...                  ...
# 2545       TED2017  1496707200          4     Duarte Geraldino
# 2546       TED2017  1492992000          3  Armando Azua-Bustos
# 2547       TED2017  1492992000          1       Radhika Nagpal
# 2548  TEDxMileHigh  1499472000          1     Theo E.J. Wilson
# 2549       TED2017  1492992000          1    Karoliina Korppoo
#
#                                                    name  num_speaker  \
# 0             Ken Robinson: Do schools kill creativity?            1
# 1                  Al Gore: Averting the climate crisis            1
# 2                         David Pogue: Simplicity sells            1
# 3                    Majora Carter: Greening the ghetto            1
# 4         Hans Rosling: The best stats you've ever seen            1
# ...                                                 ...          ...
# 2545  Duarte Geraldino: What we're missing in the de...            1
# 2546  Armando Azua-Bustos: The most Martian place on...            1
# 2547  Radhika Nagpal: What intelligent machines can ...            1
# 2548  Theo E.J. Wilson: A black man goes undercover ...            1
# 2549  Karoliina Korppoo: How a video game might help...            1
#
#       published_date                                            ratings  \
# 0         1151367060  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1         1151367060  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2         1151367060  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3         1151367060  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4         1151440680  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# ...              ...                                                ...
# 2545      1505851216  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2546      1505919737  [{'id': 22, 'name': 'Fascinating', 'count': 32...
# 2547      1506006095  [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# 2548      1506024042  [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# 2549      1506092422  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks  \
# 0     [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1     [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2     [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3     [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4     [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
# ...                                                 ...
# 2545  [{'id': 2596, 'hero': 'https://pe.tedcdn.com/i...
# 2546  [{'id': 2491, 'hero': 'https://pe.tedcdn.com/i...
# 2547  [{'id': 2346, 'hero': 'https://pe.tedcdn.com/i...
# 2548  [{'id': 2512, 'hero': 'https://pe.tedcdn.com/i...
# 2549  [{'id': 2682, 'hero': 'https://pe.tedcdn.com/i...
#
#                         speaker_occupation  \
# 0                          Author/educator
# 1                         Climate advocate
# 2                     Technology columnist
# 3       Activist for environmental justice
# 4     Global health expert; data visionary
# ...                                    ...
# 2545                            Journalist
# 2546                        Astrobiologist
# 2547                     Robotics engineer
# 2548                   Public intellectual
# 2549                         Game designer
#
#                                                    tags  \
# 0     ['children', 'creativity', 'culture', 'dance',...
# 1     ['alternative energy', 'cars', 'climate change...
# 2     ['computers', 'entertainment', 'interface desi...
# 3     ['MacArthur grant', 'activism', 'business', 'c...
# 4     ['Africa', 'Asia', 'Google', 'demo', 'economic...
# ...                                                 ...
# 2545  ['TED Residency', 'United States', 'community'...
# 2546  ['Mars', 'South America', 'TED Fellows', 'astr...
# 2547  ['AI', 'ants', 'fish', 'future', 'innovation',...
# 2548  ['Internet', 'TEDx', 'United States', 'communi...
# 2549  ['cities', 'design', 'future', 'infrastructure...
#
#                                                   title  \
# 0                           Do schools kill creativity?
# 1                           Averting the climate crisis
# 2                                      Simplicity sells
# 3                                   Greening the ghetto
# 4                       The best stats you've ever seen
# ...                                                 ...
# 2545  What we're missing in the debate about immigra...
# 2546                    The most Martian place on Earth
# 2547  What intelligent machines can learn from a sch...
# 2548       A black man goes undercover in the alt-right
# 2549  How a video game might help us build better ci...
#
#                                                     url     views
# 0     https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1     https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2     https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3     https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4     https://www.ted.com/talks/hans_rosling_shows_t...  12005869
# ...                                                 ...       ...
# 2545  https://www.ted.com/talks/duarte_geraldino_wha...    450430
# 2546  https://www.ted.com/talks/armando_azua_bustos_...    417470
# 2547  https://www.ted.com/talks/radhika_nagpal_what_...    375647
# 2548  https://www.ted.com/talks/theo_e_j_wilson_a_bl...    419309
# 2549  https://www.ted.com/talks/karoliina_korppoo_ho...    391721
#
# [2550 rows x 17 columns]

# %% [markdown]
# ### Question 1. How would you check the number of rows and columns?

# %%
df.shape
# Out:
# (2550, 17)

# %% [markdown]
# > Note that `object columns` are usually `strings`, but can also be arbitrary Python objects such as `lists` and `dictionaries`.
#
# > #### <font color = "red"> See **Chapter 12 and 13** of `The Coder's Apprentice` for more details. </font>

# %% [markdown]
# ### Question 2. How would you count the number of missing values in each column?

# %%
df.isna().sum()
# Out:
# comments              0
# description           0
# duration              0
# event                 0
# film_date             0
# languages             0
# main_speaker          0
# name                  0
# num_speaker           0
# published_date        0
# ratings               0
# related_talks         0
# speaker_occupation    6
# tags                  0
# title                 0
# url                   0
# views                 0
# dtype: int64

# %% [markdown]
# ### Question 3.1. Which talks give rise to the most online discussion? First, please sort by the number of first-level comments (though note that this is `biased in favor of older talks`).

# %%
(
    df
    .sort_values(
        by = 'comments', 
        ascending = False
    )
)
# Out:
#       comments                                        description  duration  \
# 96        6404  Richard Dawkins urges all atheists to openly s...      1750
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 644       3356  Questions of good and evil, right and wrong ar...      1386
# 201       2877  Jill Bolte Taylor got a research opportunity f...      1099
# 1787      2673  Our consciousness is a fundamental aspect of o...      1117
# ...        ...                                                ...       ...
# 2407         5  Grammy-winning Silk Road Ensemble display thei...       389
# 2528         3  Digital archaeologist Chance Coughenour is usi...       717
# 2542         3  In the century-old statues that occupy Cape To...       795
# 2501         3  Meet Françoise Mouly, The New Yorker's art dir...       509
# 2534         2  What the astronauts felt when they saw Earth f...       725
#
#                event   film_date  languages         main_speaker  \
# 96           TED2002  1012608000         42      Richard Dawkins
# 0            TED2006  1140825600         60         Ken Robinson
# 644          TED2010  1265846400         39           Sam Harris
# 201          TED2008  1204070400         49    Jill Bolte Taylor
# 1787         TED2014  1395100800         33       David Chalmers
# ...              ...         ...        ...                  ...
# 2407         TED2016  1455494400          0   Silk Road Ensemble
# 2528     TEDxHamburg  1465344000          5    Chance Coughenour
# 2542  TEDGlobal 2017  1503792000          1   Sethembile Msezane
# 2501          TEDNYC  1488931200         12      Françoise Mouly
# 2534       TEDxSkoll  1491523200          1       Benjamin Grant
#
#                                                    name  num_speaker  \
# 96                    Richard Dawkins: Militant atheism            1
# 0             Ken Robinson: Do schools kill creativity?            1
# 644      Sam Harris: Science can answer moral questions            1
# 201             Jill Bolte Taylor: My stroke of insight            1
# 1787  David Chalmers: How do you explain consciousness?            1
# ...                                                 ...          ...
# 2407                    Silk Road Ensemble: "Turceasca"            1
# 2528  Chance Coughenour: How your pictures can help ...            1
# 2542  Sethembile Msezane: Living sculptures that sta...            1
# 2501  Françoise Mouly: The stories behind The New Yo...            1
# 2534  Benjamin Grant: What it feels like to see Eart...            1
#
#       published_date                                            ratings  \
# 96        1176689220  [{'id': 3, 'name': 'Courageous', 'count': 3236...
# 0         1151367060  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 644       1269249180  [{'id': 8, 'name': 'Informative', 'count': 923...
# 201       1205284200  [{'id': 22, 'name': 'Fascinating', 'count': 14...
# 1787      1405350484  [{'id': 25, 'name': 'OK', 'count': 280}, {'id'...
# ...              ...                                                ...
# 2407      1489759215  [{'id': 1, 'name': 'Beautiful', 'count': 80}, ...
# 2528      1504209631  [{'id': 9, 'name': 'Ingenious', 'count': 16}, ...
# 2542      1505488093  [{'id': 1, 'name': 'Beautiful', 'count': 41}, ...
# 2501      1501770244  [{'id': 7, 'name': 'Funny', 'count': 10}, {'id...
# 2534      1504814438  [{'id': 10, 'name': 'Inspiring', 'count': 46},...
#
#                                           related_talks  \
# 96    [{'id': 86, 'hero': 'https://pe.tedcdn.com/ima...
# 0     [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 644   [{'id': 666, 'hero': 'https://pe.tedcdn.com/im...
# 201   [{'id': 184, 'hero': 'https://pe.tedcdn.com/im...
# 1787  [{'id': 1308, 'hero': 'https://pe.tedcdn.com/i...
# ...                                                 ...
# 2407  [{'id': 2611, 'hero': 'https://pe.tedcdn.com/i...
# 2528  [{'id': 2673, 'hero': 'https://pe.tedcdn.com/i...
# 2542  [{'id': 2873, 'hero': 'https://pe.tedcdn.com/i...
# 2501  [{'id': 2479, 'hero': 'https://pe.tedcdn.com/i...
# 2534  [{'id': 2511, 'hero': 'https://pe.tedcdn.com/i...
#
#                speaker_occupation  \
# 96         Evolutionary biologist
# 0                 Author/educator
# 644   Neuroscientist, philosopher
# 201                Neuroanatomist
# 1787                  Philosopher
# ...                           ...
# 2407            Musical explorers
# 2528        Digital archaeologist
# 2542                       Artist
# 2501                   Art editor
# 2534                       Author
#
#                                                    tags  \
# 96    ['God', 'atheism', 'culture', 'religion', 'sci...
# 0     ['children', 'creativity', 'culture', 'dance',...
# 644   ['culture', 'evolutionary psychology', 'global...
# 201   ['biology', 'brain', 'consciousness', 'global ...
# 1787  ['brain', 'consciousness', 'neuroscience', 'ph...
# ...                                                 ...
# 2407      ['art', 'live music', 'music', 'performance']
# 2528  ['TEDx', 'ancient world', 'archaeology', 'cons...
# 2542  ['Africa', 'activism', 'art', 'community', 'hi...
# 2501  ['TEDNYC', 'art', 'creativity', 'culture', 'de...
# 2534  ['TEDx', 'art', 'climate change', 'environment...
#
#                                                   title  \
# 96                                     Militant atheism
# 0                           Do schools kill creativity?
# 644                  Science can answer moral questions
# 201                                My stroke of insight
# 1787                  How do you explain consciousness?
# ...                                                 ...
# 2407                                        "Turceasca"
# 2528    How your pictures can help reclaim lost history
# 2542  Living sculptures that stand for history's truths
# 2501  The stories behind The New Yorker's iconic covers
# 2534         What it feels like to see Earth from space
#
#                                                     url     views
# 96    https://www.ted.com/talks/richard_dawkins_on_m...   4374792
# 0     https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 644   https://www.ted.com/talks/sam_harris_science_c...   3433437
# 201   https://www.ted.com/talks/jill_bolte_taylor_s_...  21190883
# 1787  https://www.ted.com/talks/david_chalmers_how_d...   2162764
# ...                                                 ...       ...
# 2407  https://www.ted.com/talks/silk_road_ensemble_t...    640734
# 2528  https://www.ted.com/talks/chance_coughenour_ho...    539207
# 2542  https://www.ted.com/talks/sethembile_msezane_l...    542088
# 2501  https://www.ted.com/talks/francoise_mouly_the_...    839040
# 2534  https://www.ted.com/talks/benjamin_grant_what_...    646174
#
# [2550 rows x 17 columns]

# %% [markdown]
# #### Question 3.2. Please `correct for the bias` in favor of older talks `by calculating the number of comments per view`.

# %%
df['comments_per_view'] =\
(
    df.eval('comments / views')
)

df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# 1           Al Gore: Averting the climate crisis            1      1151367060
# 2                  David Pogue: Simplicity sells            1      1151367060
# 3             Majora Carter: Greening the ghetto            1      1151367060
# 4  Hans Rosling: The best stats you've ever seen            1      1151440680
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4  [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
#
#                      speaker_occupation  \
# 0                       Author/educator
# 1                      Climate advocate
# 2                  Technology columnist
# 3    Activist for environmental justice
# 4  Global health expert; data visionary
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
# 2  ['computers', 'entertainment', 'interface desi...
# 3  ['MacArthur grant', 'activism', 'business', 'c...
# 4  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869
#
#    comments_per_view
# 0           0.000096
# 1           0.000083
# 2           0.000076
# 3           0.000118
# 4           0.000049

# %% [markdown]
# > #### You will find that, for every view of the same-sex marriage talk, there are 0.002 comments.

# %% [markdown]
# #### Question 3.3. Please make this more interpretable by `inverting` the calculation.

# %%
df['views_per_comment'] =\
(
    df.eval('views / comments')
)

df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# 1           Al Gore: Averting the climate crisis            1      1151367060
# 2                  David Pogue: Simplicity sells            1      1151367060
# 3             Majora Carter: Greening the ghetto            1      1151367060
# 4  Hans Rosling: The best stats you've ever seen            1      1151440680
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4  [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
#
#                      speaker_occupation  \
# 0                       Author/educator
# 1                      Climate advocate
# 2                  Technology columnist
# 3    Activist for environmental justice
# 4  Global health expert; data visionary
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
# 2  ['computers', 'entertainment', 'interface desi...
# 3  ['MacArthur grant', 'activism', 'business', 'c...
# 4  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869
#
#    comments_per_view  views_per_comment
# 0           0.000096       10372.745443
# 1           0.000083       12077.433962
# 2           0.000076       13195.903226
# 3           0.000118        8487.750000
# 4           0.000049       20245.984823

# %% [markdown]
# > Please consider the `limitations` and `biases` of your data, making your results understandable (`interpretable`).

# %% [markdown]
# ### <font color = "blue"> Let's `visualize` the distribution of comments </font>
#
# > #### <font color = "red"> See **Chapter 4** of `Python Data Science Handbook` for a quick reference for matplotlib </font>
#
# > #### <font color = "red"> For in-depth details, use https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html </font>

# %% [markdown]
# #### Question 3.4. Please create a `Line chart`, but it seems NOT useful here.

# %%
(
    plt.plot(
        df.index, 
        df['comments']
    )
);

# %% [markdown]
# #### Question 3.5. Please create a `Histogram`--it displays the frequency distribution of a single numeric variable.

# %%
plt.hist(df['comments']);

# %% [markdown]
# #### Question 3.6. Please modify the plot to be more informative by setting a cut-off for inclusion (i.e., more than 1,000 comments).

# %%
inclusion =\
(
    df[df['comments'] > 1_000]
)

plt.hist(inclusion['comments']);

# %% [markdown]
# >  Now, before we move on, let's check how many observations we removed from the plot.

# %%
print(f'removed: {len(df) - len(inclusion)} / {len(df)}')
# Out:
# removed: 2519 / 2550

# %% [markdown]
# ### Question 4.1. Here's a question for an expansion of your vocabulary: please obtain the above using the query method.
#
# > #### <font color = "red"> Please check the following for more details </font>
# > - `Python Data Science Handbook`
#     - *Chapter 3*: Data Manipulation with Pandas
#         - *Section 12*: High-Performance Pandas: `eval()` and `query()`

# %%
inclusion_query = \
(
    df.query('`comments` > 1_000')
)

print(f'removed: {len(df) - len(inclusion)} / {len(df)}')
# Out:
# removed: 2519 / 2550

# %% [markdown]
# #### Question 4.2. Here's a question for yet another expansion of your vocabulary: please write this using the `loc` accessor.
#
# > #### <font color = "red"> Please check the following for more details on the differences between loc and iloc.
#
# > - `** NOTE: You may ignore ix as it has been deprecated**` </font>
#
# > - `Python Data Science Handbook`
#     - *Chapter 3*: Data Manipulation with Pandas
#         - *Section 2*: Data Indexing and Selection
#             - *Subsection 3*: Indexers: loc, iloc, and ix

# %%
(
    df
    .loc
    [
        df['comments'] > 1_000
    ]
)
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 96        6404  Richard Dawkins urges all atheists to openly s...      1750
# 201       2877  Jill Bolte Taylor got a research opportunity f...      1099
# 381       1604  Elizabeth Gilbert muses on the impossible thin...      1149
# 500       1094  Career analyst Dan Pink examines the puzzle of...      1116
# 530       1155  Our lives, our cultures, are composed of many ...      1129
# 553       1329  At TEDIndia, Pranav Mistry demos several tools...       830
# 614       1137  Sharing powerful stories from his anti-obesity...      1313
# 641       1309  Games like World of Warcraft give players the ...      1203
# 644       3356  Questions of good and evil, right and wrong ar...      1386
# 661       2272  Vaccine-autism claims, "Frankenfood" bans, the...      1141
# 667       1545  Legendary skeptic James Randi takes a fatal do...      1039
# 677       1930  Simon Sinek has a simple but powerful model fo...      1084
# 692       1234  In this poignant, funny follow-up to his fable...      1008
# 694       1502  Filmmaker Sharmeen Obaid-Chinoy takes on a ter...       489
# 730       1217  Listening to stories widens the imagination; t...      1185
# 837       1927  Brené Brown studies human connection -- our ab...      1219
# 840       2374  Lesley Hazleton sat down one day to read the K...       573
# 954       2492  Janet Echelman found her true voice as an arti...       566
# 1030      1627  At his Stanford University commencement speech...       904
# 1043      1058  We feel instinctively that societies with huge...      1014
# 1114      1328  What aspects of religion should atheists (resp...      1160
# 1163      1155  In a culture where being social and outgoing a...      1144
# 1346      2290  Body language affects how others see us, but i...      1262
# 1043  Richard Wilkinson: How economic inequality har...            1
# 1114                       Alain de Botton: Atheism 2.0            1
# 1163                Susan Cain: The power of introverts            1
# 1346  Amy Cuddy: Your body language may shape who yo...            1
# 1448  Allan Savory: How to fight desertification and...            1
# 1450  Ron Finley: A guerilla gardener in South Centr...            1
# 1453  Dan Pallotta: The way we think about charity i...            1
# 1537        Eric X. Li: A tale of two political systems            1
# 1779  Simon Anholt: Which country does the most good...            1
# 1787  David Chalmers: How do you explain consciousness?            1
# 1940                Monica Lewinsky: The price of shame            1
#
#       published_date                                            ratings  \
# 0         1151367060  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 96        1176689220  [{'id': 3, 'name': 'Courageous', 'count': 3236...
# 201       1205284200  [{'id': 22, 'name': 'Fascinating', 'count': 14...
# 381       1234141200  [{'id': 1, 'name': 'Beautiful', 'count': 4027}...
# 500       1251075600  [{'id': 22, 'name': 'Fascinating', 'count': 38...
# 530       1254877200  [{'id': 1, 'name': 'Beautiful', 'count': 5607}...
# 553       1258333200  [{'id': 23, 'name': 'Jaw-dropping', 'count': 8...
# 614       1265902560  [{'id': 23, 'name': 'Jaw-dropping', 'count': 1...
# 641       1268816460  [{'id': 22, 'name': 'Fascinating', 'count': 15...
# 644       1269249180  [{'id': 8, 'name': 'Informative', 'count': 923...
# 661       1271065080  [{'id': 3, 'name': 'Courageous', 'count': 702}...
# 667       1271690880  [{'id': 8, 'name': 'Informative', 'count': 757...
# 677       1272965460  [{'id': 21, 'name': 'Unconvincing', 'count': 9...
# 692       1274691960  [{'id': 7, 'name': 'Funny', 'count': 3000}, {'...
# 694       1274865960  [{'id': 23, 'name': 'Jaw-dropping', 'count': 3...
# 730       1279262220  [{'id': 10, 'name': 'Inspiring', 'count': 2251...
# 837       1293115500  [{'id': 10, 'name': 'Inspiring', 'count': 2144...
# 840       1294155180  [{'id': 3, 'name': 'Courageous', 'count': 488}...
# 954       1307489760  [{'id': 23, 'name': 'Jaw-dropping', 'count': 3...
# 1030      1317868920  [{'id': 10, 'name': 'Inspiring', 'count': 1729...
# 1043      1319468736  [{'id': 22, 'name': 'Fascinating', 'count': 75...
# 1114      1326812704  [{'id': 21, 'name': 'Unconvincing', 'count': 3...
# 1163      1330720092  [{'id': 24, 'name': 'Persuasive', 'count': 336...
# 1346      1349103608  [{'id': 23, 'name': 'Jaw-dropping', 'count': 3...
# 1448      1362412271  [{'id': 24, 'name': 'Persuasive', 'count': 114...
# 1450      1362586018  [{'id': 9, 'name': 'Ingenious', 'count': 668},...
# 1453      1363014731  [{'id': 24, 'name': 'Persuasive', 'count': 213...
# 1537      1372692970  [{'id': 22, 'name': 'Fascinating', 'count': 84...
# 1779      1404313134  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
# 1787      1405350484  [{'id': 25, 'name': 'OK', 'count': 280}, {'id'...
# 1940      1426894031  [{'id': 3, 'name': 'Courageous', 'count': 8668...
#
#                                           related_talks  \
# 0     [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 96    [{'id': 86, 'hero': 'https://pe.tedcdn.com/ima...
# 201   [{'id': 184, 'hero': 'https://pe.tedcdn.com/im...
# 381   [{'id': 250, 'hero': 'https://pe.tedcdn.com/im...
# 500   [{'id': 548, 'hero': 'https://pe.tedcdn.com/im...
# 530   [{'id': 159, 'hero': 'https://pe.tedcdn.com/im...
# 553   [{'id': 481, 'hero': 'https://pe.tedcdn.com/im...
# 614   [{'id': 10, 'hero': 'https://pe.tedcdn.com/ima...
# 641   [{'id': 146, 'hero': 'https://pe.tedcdn.com/im...
# 644   [{'id': 666, 'hero': 'https://pe.tedcdn.com/im...
# 661   [{'id': 801, 'hero': 'https://pe.tedcdn.com/im...
# 667   [{'id': 22, 'hero': 'https://pe.tedcdn.com/ima...
# 677   [{'id': 814, 'hero': 'https://pe.tedcdn.com/im...
# 692   [{'id': 66, 'hero': 'https://pe.tedcdn.com/ima...
# 694   [{'id': 171, 'hero': 'https://pe.tedcdn.com/im...
# 730   [{'id': 652, 'hero': 'https://pe.tedcdn.com/im...
# 837   [{'id': 1391, 'hero': 'https://pe.tedcdn.com/i...
# 840   [{'id': 1772, 'hero': 'https://pe.tedcdn.com/i...
# 954   [{'id': 453, 'hero': 'https://pe.tedcdn.com/im...
# 1030  [{'id': 848, 'hero': 'https://pe.tedcdn.com/im...
# 1043  [{'id': 1101, 'hero': 'https://pe.tedcdn.com/i...
# 1114  [{'id': 605, 'hero': 'https://pe.tedcdn.com/im...
# 1163  [{'id': 1042, 'hero': 'https://pe.tedcdn.com/i...
# 1346  [{'id': 605, 'hero': 'https://pe.tedcdn.com/im...
# 1448  [{'id': 1018, 'hero': 'https://pe.tedcdn.com/i...
# 1450  [{'id': 1306, 'hero': 'https://pe.tedcdn.com/i...
# 1453  [{'id': 977, 'hero': 'https://pe.tedcdn.com/im...
# 1537  [{'id': 1554, 'hero': 'https://pe.tedcdn.com/i...
# 1779  [{'id': 62, 'hero': 'https://pe.tedcdn.com/ima...
# 1787  [{'id': 1308, 'hero': 'https://pe.tedcdn.com/i...
# 1940  [{'id': 2073, 'hero': 'https://pe.tedcdn.com/i...
#
#                                   speaker_occupation  \
# 0                                    Author/educator
# 96                            Evolutionary biologist
# 201                                   Neuroanatomist
# 381                                           Writer
# 500                                   Career analyst
# 530                                         Novelist
# 553   Director of research, Samsung Research America
# 614                                   Chef, activist
# 641                                    Game Designer
# 644                      Neuroscientist, philosopher
# 661                                           Writer
# 667                             Skeptic and conjuror
# 677                                Leadership expert
# 692                                  Author/educator
# 694                                        Filmmaker
# 730                                         Novelist
# 837                         Vulnerability researcher
# 840                             Writer, psychologist
# 954                                           Artist
# 1030                                       Visionary
# 1043                        Public health researcher
# 1114                                     Philosopher
# 1163                             Quiet revolutionary
# 1346                             Social psychologist
# 1448                     Grassland ecosystem pioneer
# 1450                                        Gardener
# 1453                       Author, speaker, reformer
# 1537                Investor and political scientist
# 1779                                  Policy advisor
# 1787                                     Philosopher
# 1940                                 Social activist
#
#                                                    tags  \
# 0     ['children', 'creativity', 'culture', 'dance',...
# 96    ['God', 'atheism', 'culture', 'religion', 'sci...
# 201   ['biology', 'brain', 'consciousness', 'global ...
# 381   ['creativity', 'culture', 'entertainment', 'pe...
# 500   ['brain', 'business', 'creativity', 'motivatio...
# 530   ['Africa', 'books', 'culture', 'identity', 'st...
# 553     ['demo', 'design', 'open-source', 'technology']
# 614   ['business', 'education', 'food', 'global issu...
# 641   ['computers', 'design', 'entertainment', 'gami...
# 644   ['culture', 'evolutionary psychology', 'global...
# 661   ['global issues', 'medicine', 'religion', 'sci...
# 667           ['culture', 'health', 'magic', 'science']
# 677   ['TEDx', 'business', 'entrepreneur', 'leadersh...
# 692   ['TED Brain Trust', 'children', 'creativity', ...
# 694   ['TED Fellows', 'children', 'culture', 'film',...
# 730   ['culture', 'novel', 'politics', 'storytelling...
# 837   ['TEDx', 'communication', 'culture', 'depressi...
# 840   ['TEDx', 'culture', 'global issues', 'journali...
# 954   ['art', 'cities', 'culture', 'data', 'design',...
# 1030  ['business', 'computers', 'creativity', 'death...
# 1043  ['culture', 'data', 'global issues', 'inequali...
# 1114   ['atheism', 'culture', 'philosophy', 'religion']
# 1163  ['business', 'culture', 'introvert', 'psycholo...
# 1346  ['body language', 'brain', 'business', 'psycho...
# 1448         ['agriculture', 'climate change', 'green']
# 1450  ['agriculture', 'culture', 'food', 'garden', '...
# 1453  ['business', 'culture', 'global issues', 'phil...
# 1537  ['Asia', 'business', 'china', 'democracy', 'gl...
# 1779  ['Foreign Policy', 'global issues', 'governmen...
# 1787  ['brain', 'consciousness', 'neuroscience', 'ph...
# 1940  ['communication', 'media', 'social media', 'su...
#
#                                                   title  \
# 0                           Do schools kill creativity?
# 96                                     Militant atheism
# 201                                My stroke of insight
# 381                        Your elusive creative genius
# 500                            The puzzle of motivation
# 530                        The danger of a single story
# 553    The thrilling potential of SixthSense technology
# 614                        Teach every child about food
# 641                      Gaming can make a better world
# 644                  Science can answer moral questions
# 661                        The danger of science denial
# 667                      Homeopathy, quackery and fraud
# 677                    How great leaders inspire action
# 692                   Bring on the learning revolution!
# 694                 Inside a school for suicide bombers
# 730                             The politics of fiction
# 837                          The power of vulnerability
# 840                                On reading the Koran
# 954                        Taking imagination seriously
# 1030                         How to live before you die
# 1043            How economic inequality harms societies
# 1114                                        Atheism 2.0
# 1163                            The power of introverts
# 1346           Your body language may shape who you are
# 1448  How to fight desertification and reverse clima...
# 1450            A guerilla gardener in South Central LA
# 1453       The way we think about charity is dead wrong
# 1537                    A tale of two political systems
# 1779    Which country does the most good for the world?
# 1787                  How do you explain consciousness?
# 1940                                 The price of shame
#
#                                                     url     views  \
# 0     https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 96    https://www.ted.com/talks/richard_dawkins_on_m...   4374792
# 201   https://www.ted.com/talks/jill_bolte_taylor_s_...  21190883
# 381   https://www.ted.com/talks/elizabeth_gilbert_on...  13155478
# 500    https://www.ted.com/talks/dan_pink_on_motivation  18830983
# 530   https://www.ted.com/talks/chimamanda_adichie_t...  13298341
# 553   https://www.ted.com/talks/pranav_mistry_the_th...  16097077
# 614              https://www.ted.com/talks/jamie_oliver   7638978
# 641   https://www.ted.com/talks/jane_mcgonigal_gamin...   4573252
# 644   https://www.ted.com/talks/sam_harris_science_c...   3433437
# 661   https://www.ted.com/talks/michael_specter_the_...   1838628
# 667               https://www.ted.com/talks/james_randi   2611707
# 677   https://www.ted.com/talks/simon_sinek_how_grea...  34309432
# 692   https://www.ted.com/talks/sir_ken_robinson_bri...   7266316
# 694   https://www.ted.com/talks/sharmeen_obaid_chino...   1057238
# 730   https://www.ted.com/talks/elif_shafak_the_poli...   1763449
# 837   https://www.ted.com/talks/brene_brown_on_vulne...  31168150
# 840   https://www.ted.com/talks/lesley_hazelton_on_r...   1847256
# 954            https://www.ted.com/talks/janet_echelman   1832930
# 1030  https://www.ted.com/talks/steve_jobs_how_to_li...   8744428
# 1043        https://www.ted.com/talks/richard_wilkinson   2487499
# 1114  https://www.ted.com/talks/alain_de_botton_athe...   2203020
# 1163  https://www.ted.com/talks/susan_cain_the_power...  17629275
# 1346  https://www.ted.com/talks/amy_cuddy_your_body_...  43155405
# 1448  https://www.ted.com/talks/allan_savory_how_to_...   4191678
# 1450  https://www.ted.com/talks/ron_finley_a_guerill...   3005687
# 1453  https://www.ted.com/talks/dan_pallotta_the_way...   4259204
# 1537  https://www.ted.com/talks/eric_x_li_a_tale_of_...   2449736
# 1779  https://www.ted.com/talks/simon_anholt_which_c...   4548276
# 1787  https://www.ted.com/talks/david_chalmers_how_d...   2162764
# 1940  https://www.ted.com/talks/monica_lewinsky_the_...  11443190
#
#       comments_per_view  views_per_comment
# 0              0.000096       10372.745443
# 96             0.001464         683.134291
# 201            0.000136        7365.618005
# 381            0.000122        8201.669576
# 500            0.000058       17212.964351
# 530            0.000087       11513.715152
# 553            0.000083       12112.172310
# 614            0.000149        6718.538259
# 641            0.000286        3493.699007
# 644            0.000977        1023.074195
# 661            0.001236         809.255282
# 667            0.000592        1690.425243
# 677            0.000056       17776.907772
# 692            0.000170        5888.424635
# 694            0.001421         703.886818
# 730            0.000690        1449.013147
# 837            0.000062       16174.442138
# 840            0.001285         778.119629
# 954            0.001360         735.525682
# 1030           0.000186        5374.571604
# 1043           0.000425        2351.133270
# 1114           0.000603        1658.900602
# 1163           0.000066       15263.441558
# 1346           0.000053       18845.155022
# 1448           0.000378        2642.924338
# 1450           0.000470        2127.167021
# 1453           0.000341        2935.357684
# 1537           0.000669        1493.741463
# 1779           0.000271        3685.799028
# 1787           0.001236         809.114852
# 1940           0.000118        8445.158672

# %% [markdown]
# > Let's increase the number of bins (intervals) to see more detail.

# %%
plt.hist(inclusion['comments'], bins = 20);

# %% [markdown]
# #### Question 4.3. Please create a boxplot. Boxplot can also show distributions, but it's far less useful for concentrated distributions because of outliers.

# %%
plt.boxplot(inclusion['comments']);

# %% [markdown]
# ### <font color = "blue"> Let me reiterate learning pointers in an explicit manner so that you can keep this in mind. </font>
#
# 1. `Choose your plot type` based on the question you are answering and the data type(s) you are working with
# 2. `Use pandas one-liners` to iterate through plots quickly
# 3. `Try modifying the plot defaults`
#
# > ***Yes, creating plots involves your decision-making***

# %% [markdown]
# #### Question 4.4. Please plot the number of talks that took place each year.

# %% [markdown]
# > Let's calculate the average delay between filming and publishing.

# %%
df['delay'] =\
(
    df
    .eval(
        'published_date - film_date'
    )
)

print(f'Average delay between filming and publishing: {df["delay"].mean()}')
# Out:
# Average delay between filming and publishing: 21597713.70352941

# %% [markdown]
# > Okay. `event` column does not always include the year

# %% [markdown]
# > Note that `film_date` denotes `Unix timestamp of the filming`. Have a look at it :)

# %%
df['film_date'].describe()
# Out:
# count    2.550000e+03
# mean     1.321928e+09
# std      1.197391e+08
# min      7.464960e+07
# 25%      1.257466e+09
# 50%      1.333238e+09
# 75%      1.412964e+09
# max      1.503792e+09
# Name: film_date, dtype: float64

# %% [markdown]
# > Results don't look right...
#
# > What would you do? You may use `to_datetime()`

# %%
df['film_date'] =\
(
    pd.to_datetime(df['film_date'])
)

# %% [markdown]
# > Still, it does NOT look fine...

# %% [markdown]
# ### <font color = "red"> For your information, [pandas documentation for `to_datetime`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html) </font>

# %% [markdown]
# > #### <font color = "blue"> Please use argument `unit` and set it at `"s"` </font>

# %%
df['film_date'] =\
(
    pd.to_datetime(
        df['film_date'], 
        unit = 's'
    )
)

df['published_date'] =\
(
    pd.to_datetime(
        df['published_date'], 
        unit = 's'
    )
)

# %% [markdown]
# > You might want to check that event name matches film_datetime for a random sample: use, `sample()`

# %%
df.sample()
# Out:
#       comments                                        description  duration  \
# 2007       108  For the longest time, doctors basically ignore...       831
#
#         event                     film_date  languages  main_speaker  \
# 2007  TED2015 1970-01-01 00:00:01.427155200         27  Latif Nasser
#
#                                                    name  num_speaker  \
# 2007  Latif Nasser: The amazing story of the man who...            1
#
#           published_date                                            ratings  \
# 2007 2015-07-01 15:00:06  [{'id': 10, 'name': 'Inspiring', 'count': 383}...
#
#                                           related_talks speaker_occupation  \
# 2007  [{'id': 1231, 'hero': 'https://pe.tedcdn.com/i...   Radio researcher
#
#                                                    tags  \
# 2007  ['empathy', 'health', 'health care', 'history'...
#
#                                                   title  \
# 2007  The amazing story of the man who gave us moder...
#
#                                                     url    views  \
# 2007  https://www.ted.com/talks/latif_nasser_the_ama...  1531606
#
#       comments_per_view  views_per_comment    delay
# 2007           0.000071       14181.537037  8607606

# %% [markdown]
# > New column uses the datetime data type (this was an automatic conversion)

# %% [markdown]
# ##### `datetime` columns have convenient attributes under the `dt` namespace

# %%
'dt' in dir(df['film_date'])
# Out:
# True

# %% [markdown]
# > This is similar to string methods under the str namespace

# %%
'str' in dir(df['event'])
# Out:
# True

# %% [markdown]
# > Let's count the number of talks each year using value_counts()

# %%
df['talk_year'] =\
(
    df['published_date']
    .dt
    .year
    
)

talks_per_year =\
(
    df['talk_year']
    .value_counts()
    .to_frame()
)

# %% [markdown]
# ##### Let's visualize.

# %%
plt.plot(talks_per_year);

# %% [markdown]
# > points are plotted and connected in the order you give them to pandas

# %% [markdown]
# #### Question 4.5. Please sort the index before plotting

# %%
plt.plot(talks_per_year.sort_index());

# %% [markdown]
# > Check your data to understand more about what this means :)

# %%
talks_per_year.sort_index()
# Out:
#       talk_year
# 2006         50
# 2007        122
# 2008        188
# 2009        222
# 2010        257
# 2011        261
# 2012        306
# 2013        244
# 2014        240
# 2015        220
# 2016        243
# 2017        197

# %% [markdown]
# > Do note that we only have partial data for 2017

# %% [markdown]
# Before we move forward, please consider the following:
#
# - Read the documentation of your dataset
# - Use the datetime data type for dates and times
# - Check your work as you proceed
# - Exclude data if it might not be relevant to your focal point of analysis

# %% [markdown]
# ### Question 5.1. What were the "best" events in TED talks' history to attend? Let's count the number of talks (great if you value variety, but they may not be great talks)

# %%
(
    df
    .groupby('event')
    .agg(
        talk_count = (
            'event','count'
        )
    )
    .sort_values(
        by = 'talk_count',
        ascending = False
    )

)
# Out:
#                         talk_count
# event
# TED2014                         84
# TED2009                         83
# TED2013                         77
# TED2016                         77
# TED2015                         75
# ...                            ...
# TEDxEQChCh                       1
# TEDxEastEnd                      1
# TEDxEdmonton                     1
# TEDxEuston                       1
# World Science Festival           1
#
# [355 rows x 1 columns]

# %% [markdown]
# #### Question 5.2. Let's use `views` as a proxy for `quality of talk`

# %%
quality_of_talk =\
(
    df
    .groupby('event')
    .agg(
        total_views = (
            'views', 'sum'
        )
    )
)

# %% [markdown]
# #### Question 5.3. Let's find the largest values, but we don't know how many talks are being averaged

# %%
(
    quality_of_talk
    .sort_values(
        by = 'total_views', 
        ascending = False
    )
)
# Out:
#                         total_views
# event
# TED2013                   177307937
# TED2014                   174121423
# TEDGlobal 2013            170554736
# TED2015                   150826305
# TED2006                   147345533
# ...                             ...
# TEDxNASA@SiliconValley       155895
# AORN Congress                149818
# TEDxWaterloo                 138812
# TEDxIslay                    120274
# The Do Lectures              112321
#
# [355 rows x 1 columns]

# %% [markdown]
# #### Question 5.4. Let's show the number of talks along with the mean (events with the highest means had only 1 or 2 talks)

# %%
(
    df
    .groupby('event')
    .agg(
        talk_count = (
            'event','count'
        ),
        mean_views = (
            'views', 'mean'
        )
    )
)
# Out:
#                              talk_count  mean_views
# event
# AORN Congress                         1    149818.0
# Arbejdsglaede Live                    1    971594.0
# BBC TV                                1    521974.0
# Bowery Poetry Club                    1    676741.0
# Business Innovation Factory           3    304086.0
# ...                                 ...         ...
# The Do Lectures                       1    112321.0
# Toronto Youth Corps                   1   1028630.0
# University of California              2    261831.5
# Web 2.0 Expo 2008                     1    757791.0
# World Science Festival                1   3302312.0
#
# [355 rows x 2 columns]

# %% [markdown]
# #### Question 5.5. Let's calculate the total views per event

# %%
(
    df
    .groupby('event')
    .agg(
        talk_count = (
            'event','count'
        ),
        total_views = (
            'views', 'sum'
        ),
        views_per_event = (
            'views', 'mean'
        )
    )
)
# Out:
#                              talk_count  total_views  views_per_event
# event
# AORN Congress                         1       149818         149818.0
# Arbejdsglaede Live                    1       971594         971594.0
# BBC TV                                1       521974         521974.0
# Bowery Poetry Club                    1       676741         676741.0
# Business Innovation Factory           3       912258         304086.0
# ...                                 ...          ...              ...
# The Do Lectures                       1       112321         112321.0
# Toronto Youth Corps                   1      1028630        1028630.0
# University of California              2       523663         261831.5
# Web 2.0 Expo 2008                     1       757791         757791.0
# World Science Festival                1      3302312        3302312.0
#
# [355 rows x 3 columns]

# %% [markdown]
# > #### <font color = "blue"> As you have seen, please... </font>
#
# - Think creatively for how you can use the data you have to answer your question
# - Watch out for small sample sizes

# %% [markdown]
# ### Now, let's take a look at ratings data

# %% [markdown]
# > Previously, users could tag talks on the TED website (funny, inspiring, confusing, etc.)

# %%
df[['ratings']]
# Out:
#                                                 ratings
# 0     [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1     [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2     [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3     [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4     [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# ...                                                 ...
# 2545  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2546  [{'id': 22, 'name': 'Fascinating', 'count': 32...
# 2547  [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# 2548  [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# 2549  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
# [2550 rows x 1 columns]

# %% [markdown]
# > Think about two ways to examine the ratings data for the first talk

# %% [markdown]
# > Okay, this is a string not a list.

# %% [markdown]
# ### Let's convert this into something useful using Python's `ast` module (`Abstract Syntax Tree`)

# %% [markdown]
# > `literal_eval()` allows you to evaluate a string containing a Python literal or container
#
# > #### <font color = "red"> See below for my guidance </font>

# %% [markdown]
# ```python
# # if you wish to unpack data
#     YOUR_DF["variable"].apply(ast.literal_eval)
#
# # if you wish to access specific talk related data
#     YOUR_DF["variable"].apply(ast.literal_eval)[0]
#
# # if you wish to access specific talk related observations within the data
#     YOUR_DF["variable"].apply(ast.literal_eval)[0][0]
#
# # if you wish to access specific talk related observations with a particular attribute within the data
#     YOUR_DF["variable"].apply(ast.literal_eval)[0][0]["key"]
# ```

# %% [markdown]
# > If you have a string representation of something, you can retrieve what it actually represents

# %%
import ast

# %% [markdown]
# > Let's unpack the ratings data for the first talk

# %%
first_talk_ratings = df['ratings'].iloc[0]
first_talk_ratings
# Out:
# "[{'id': 7, 'name': 'Funny', 'count': 19645}, {'id': 1, 'name': 'Beautiful', 'count': 4573}, {'id': 9, 'name': 'Ingenious', 'count': 6073}, {'id': 3, 'name': 'Courageous', 'count': 3253}, {'id': 11, 'name': 'Longwinded', 'count': 387}, {'id': 2, 'name': 'Confusing', 'count': 242}, {'id': 8, 'name': 'Informative', 'count': 7346}, {'id': 22, 'name': 'Fascinating', 'count': 10581}, {'id': 21, 'name': 'Unconvincing', 'count': 300}, {'id': 24, 'name': 'Persuasive', 'count': 10704}, {'id': 23, 'name': 'Jaw-dropping', 'count': 4439}, {'id': 25, 'name': 'OK', 'count': 1174}, {'id': 26, 'name': 'Obnoxious', 'count': 209}, {'id': 10, 'name': 'Inspiring', 'count': 24924}]"

# %% [markdown]
# > Yes, now we have a list (of dictionaries)

# %% [markdown]
# ### Question 6. Let's define a function to convert an element in the ratings Series from string to list
#
# #### <font color = "blue"> USE `ast.literal_eval()` </font>

# %%
def convert_ratings_series(element):
    return ast.literal_eval(element)

# %% [markdown]
# > Let's test our function

# %%
convert_ratings_series(first_talk_ratings)
# Out:
# [{'id': 7, 'name': 'Funny', 'count': 19645},
#  {'id': 1, 'name': 'Beautiful', 'count': 4573},
#  {'id': 9, 'name': 'Ingenious', 'count': 6073},
#  {'id': 3, 'name': 'Courageous', 'count': 3253},
#  {'id': 11, 'name': 'Longwinded', 'count': 387},
#  {'id': 2, 'name': 'Confusing', 'count': 242},
#  {'id': 8, 'name': 'Informative', 'count': 7346},
#  {'id': 22, 'name': 'Fascinating', 'count': 10581},
#  {'id': 21, 'name': 'Unconvincing', 'count': 300},
#  {'id': 24, 'name': 'Persuasive', 'count': 10704},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 4439},
#  {'id': 25, 'name': 'OK', 'count': 1174},
#  {'id': 26, 'name': 'Obnoxious', 'count': 209},
#  {'id': 10, 'name': 'Inspiring', 'count': 24924}]

# %% [markdown]
# > Note that Series `apply` method applies a function to every element in a Series, returning a Series.

# %%
df['ratings'].apply(ast.literal_eval)
# Out:
# 0       [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1       [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2       [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3       [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4       [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#                               ...
# 2545    [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2546    [{'id': 22, 'name': 'Fascinating', 'count': 32...
# 2547    [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# 2548    [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# 2549    [{'id': 21, 'name': 'Unconvincing', 'count': 2...
# Name: ratings, Length: 2550, dtype: object

# %% [markdown]
# > #### <font color = "blue"> `lambda` is a shorter alternative</blue>
#
# > #### <font color = "red">Please check the following for more details</font>
# > - `Coder's Apprentice`
#     - *Chapter 8*: Functions
#         - *Section 6*: Anonymous functions

# %%
func_lambda = lambda x : ast.literal_eval(x)
func_lambda(first_talk_ratings)
# Out:
# [{'id': 7, 'name': 'Funny', 'count': 19645},
#  {'id': 1, 'name': 'Beautiful', 'count': 4573},
#  {'id': 9, 'name': 'Ingenious', 'count': 6073},
#  {'id': 3, 'name': 'Courageous', 'count': 3253},
#  {'id': 11, 'name': 'Longwinded', 'count': 387},
#  {'id': 2, 'name': 'Confusing', 'count': 242},
#  {'id': 8, 'name': 'Informative', 'count': 7346},
#  {'id': 22, 'name': 'Fascinating', 'count': 10581},
#  {'id': 21, 'name': 'Unconvincing', 'count': 300},
#  {'id': 24, 'name': 'Persuasive', 'count': 10704},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 4439},
#  {'id': 25, 'name': 'OK', 'count': 1174},
#  {'id': 26, 'name': 'Obnoxious', 'count': 209},
#  {'id': 10, 'name': 'Inspiring', 'count': 24924}]

# %% [markdown]
# > An even shorter alternative is to apply the function directly (without lambda)

# %%
func_wo_lambda =\
(
    ast
    .literal_eval(first_talk_ratings)
)

# %% [markdown]
# > Let's check that the new Series looks as expected

# %%
func_lambda(first_talk_ratings) == func_wo_lambda
# Out:
# True

# %% [markdown]
# > Each element in the Series is a list

# %%
func_wo_lambda
# Out:
# [{'id': 7, 'name': 'Funny', 'count': 19645},
#  {'id': 1, 'name': 'Beautiful', 'count': 4573},
#  {'id': 9, 'name': 'Ingenious', 'count': 6073},
#  {'id': 3, 'name': 'Courageous', 'count': 3253},
#  {'id': 11, 'name': 'Longwinded', 'count': 387},
#  {'id': 2, 'name': 'Confusing', 'count': 242},
#  {'id': 8, 'name': 'Informative', 'count': 7346},
#  {'id': 22, 'name': 'Fascinating', 'count': 10581},
#  {'id': 21, 'name': 'Unconvincing', 'count': 300},
#  {'id': 24, 'name': 'Persuasive', 'count': 10704},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 4439},
#  {'id': 25, 'name': 'OK', 'count': 1174},
#  {'id': 26, 'name': 'Obnoxious', 'count': 209},
#  {'id': 10, 'name': 'Inspiring', 'count': 24924}]

# %% [markdown]
# > data type of the new Series is object

# %% [markdown]
# ##### Note that object is not just for strings.

# %%
type(func_wo_lambda)
# Out:
# list

# %% [markdown]
# #### <font color = "blue"> So far so good, remember to: </font>
#
# - Pay attention to data types in pandas
# - Use apply any time it is necessary

# %% [markdown]
# ### Question 7.1. Let's have a look at the total number of ratings received by each talk
#
# - for each talk, calculate the percentage of ratings that were negative
#
# - for each talk, calculate the average number of ratings it received per day since it was published

# %% [markdown]
# > Let's start by building a simple function

# %% [markdown]
# > Here, expected result (for each talk) is sum of count

# %%
df['ratings'].apply(ast.literal_eval)[0]
# Out:
# [{'id': 7, 'name': 'Funny', 'count': 19645},
#  {'id': 1, 'name': 'Beautiful', 'count': 4573},
#  {'id': 9, 'name': 'Ingenious', 'count': 6073},
#  {'id': 3, 'name': 'Courageous', 'count': 3253},
#  {'id': 11, 'name': 'Longwinded', 'count': 387},
#  {'id': 2, 'name': 'Confusing', 'count': 242},
#  {'id': 8, 'name': 'Informative', 'count': 7346},
#  {'id': 22, 'name': 'Fascinating', 'count': 10581},
#  {'id': 21, 'name': 'Unconvincing', 'count': 300},
#  {'id': 24, 'name': 'Persuasive', 'count': 10704},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 4439},
#  {'id': 25, 'name': 'OK', 'count': 1174},
#  {'id': 26, 'name': 'Obnoxious', 'count': 209},
#  {'id': 10, 'name': 'Inspiring', 'count': 24924}]

# %% [markdown]
# #### Question 7.2. Please pass it a list, and it returns the first element in the list, which is a dictionary

# %%
def vote_count(data):
    return data[0][0]

vote_count(df['ratings'].apply(ast.literal_eval))
# Out:
# {'id': 7, 'name': 'Funny', 'count': 19645}

# %% [markdown]
# #### Question 7.3. Let's modify the function to return the vote count.

# %%
def vote_count(data):
    return data[0][0]['count']

vote_count(df['ratings'].apply(ast.literal_eval))
# Out:
# 19645

# %% [markdown]
# #### Quesion 7.4. Let's pass it a list, and it returns a value from the first dictionary in the list

# %%
vote_count(df['ratings'].apply(ast.literal_eval))
# Out:
# 19645

# %% [markdown]
# #### Question 7.5. Let's modify the function to get the sum of count

# %%
def vote_count(data):
    sum_count = 0
    for i in range(len(data)):
        sum_count += data[i]['count']

    return sum_count

# %% [markdown]
# > Does the result look about right? Please check.

# %%
vote_count(df['ratings'].apply(ast.literal_eval)[0])
# Out:
# 93850

# %% [markdown]
# > Let's apply it to every element in the Series

# %%
df['rating_count'] = \
(
    df
    ['ratings']
    .apply(ast.literal_eval)
    .apply(vote_count)
)

# %% [markdown]
# > #### <font color = "blue"> Alternative here is to use a `generator expression`</font>
#
# > #### <font color = "red"> Please check the following for more details </font>
# > - `Think Python`: https://greenteapress.com/thinkpython2/thinkpython2.pdf
#     - *Chapter 19*: The Goodies
#         - *Section 3*: Generator expressions

# %%
generator = (vote_count(x) for x in df['ratings'].apply(ast.literal_eval))
for num in generator:
    print(num)
# Out:
# 93850
# 2936
# 2824
# 3728
# 25620
# 15356
# 5998
# 1024
# 3946
# 8327
# 1780
# 592
# 886
# 8317
# 781
# 6239
# 4679
# 1788
# 1931
# 1571
# 1177
# 5164
# 784
# 10780
# 2570
# 3544
# 4594
# 2036
# 10678
# 19834
# 14945
# 2071
# 5484
# 706
# 755
# 435
# 892
# 2021
# 1013
# 969
# 952
# 499
# 2215
# 8745
# 3292
# 2786
# 849
# 15013
# 2649
# 1746
# 1004
# 4189
# 4615
# 719
# 2957
# 2138
# 918
# 1569
# 6063
# 1474
# 571
# 927
# 3605
# 1182
# 1747
# 2367
# 3174
# 5254
# 1908
# 2002
# 676
# 1374
# 2001
# 1671
# 556
# 928
# 385
# 943
# 2438
# 1331
# 3441
# 666
# 684
# 5741
# 4350
# 2053
# 599
# 437
# 3206
# 8338
# 3303
# 1068
# 1028
# 621
# 649
# 1975
# 14904
# 1171
# 521
# 787
# 805
# 1304
# 867
# 5854
# 659
# 1042
# 3274
# 1550
# 20745
# 1354
# 1404
# 2038
# 2719
# 297
# 2796
# 477
# 409
# 12783
# 4274
# 5327
# 2676
# 3931
# 1138
# 3897
# 4960
# 5309
# 1013
# 1267
# 1943
# 2526
# 382
# 1997
# 1088
# 1201
# 810
# 448
# 10465
# 533
# 2047
# 799
# 884
# 919
# 2967
# 240
# 996
# 411
# 1442
# 557
# 827
# 649
# 509
# 334
# 583
# 981
# 461
# 417
# 1438
# 2057
# 4522
# 506
# 913
# 488
# 157
# 932
# 615
# 616
# 511
# 452
# 520
# 499
# 819
# 355
# 98
# 1412
# 132
# 933
# 309
# 119
# 270
# 427
# 236
# 708
# 201
# 143
# 365
# 382
# 683
# 97
# 426
# 310
# 588
# 737
# 817
# 174
# 770
# 366
# 1089
# 270
# 333
# 297
# 347
# 677
# 500
# 961
# 177
# 450
# 280
# 320
# 279
# 367
# 166
# 413
# 450
# 320
# 68
# 583
# 468
# 159
# 981
# 183
# 221
# 431
# 259
# 2009
# 231
# 256
# 383
# 378
# 181
# 225
# 143
# 192
# 151
# 136
# 583
# 142

# %% [markdown]
# > Try to use `lambda` to apply this method

# %%
(
    df
    ['ratings']
    .apply(ast.literal_eval)
    .apply(lambda x: vote_count(x))
)
# Out:
# 0       93850
# 1        2936
# 2        2824
# 3        3728
# 4       25620
#         ...
# 2545      192
# 2546      151
# 2547      136
# 2548      583
# 2549      142
# Name: ratings, Length: 2550, dtype: int64

# %% [markdown]
# > Another alternative is to use `pd.DataFrame()`

# %%
pd.DataFrame(
    df
    ['ratings']
    .apply(ast.literal_eval)
    .apply(vote_count)
)
# Out:
#       ratings
# 0       93850
# 1        2936
# 2        2824
# 3        3728
# 4       25620
# ...       ...
# 2545      192
# 2546      151
# 2547      136
# 2548      583
# 2549      142
#
# [2550 rows x 1 columns]

# %% [markdown]
# > use `lambda` to apply this method

# %%
pd.DataFrame(
    df
    ['ratings']
    .apply(ast.literal_eval)
    .apply(lambda x: vote_count(x))
)
# Out:
#       ratings
# 0       93850
# 1        2936
# 2        2824
# 3        3728
# 4       25620
# ...       ...
# 2545      192
# 2546      151
# 2547      136
# 2548      583
# 2549      142
#
# [2550 rows x 1 columns]

# %% [markdown]
# > Things to consider:
#
# - Write your code in small chunks
#
# - Check your work as you move forward
#
# - `lambda` is best for simple functions

# %% [markdown]
# ### Let's find:
# #### ***which occupations deliver the funniest TED talks on average?***
#
# - for each talk, calculate the most frequent rating
# - for each talk, clean the occupation data so that there's only one occupation per talk

# %% [markdown]
# ##### You might want to count the number of funny ratings

# %%
def funny_count(data):
    sum_count = 0
    for i in range(len(data)):
        if data[i]['name'] == 'Funny':
            sum_count += data[i]['count']
    return sum_count

df['funny_count'] = df['ratings'].apply(ast.literal_eval).apply(funny_count)

# %% [markdown]
# > "Funny" is not always the first dictionary in the list.

# %% [markdown]
# #### Please check ratings (not ratings_list) to see if "Funny" is always a rating type

# %%
def check_funny(data):
    return 'Funny' in data
df['contain_funny'] = df['ratings'].apply(check_funny)

# %% [markdown]
# ### Question 8. Let's write a custom function that gives us a `dictionary` that lists `talks` containing `funny` rating.

# %%
def funny_talks(data):
    return data[data['contain_funny']]['title'].to_dict()

# %% [markdown]
# > Then, you might want to examine a record in which "Funny" is not the first dictionary

# %%
df['ratings'][3]
# Out:
# "[{'id': 3, 'name': 'Courageous', 'count': 760}, {'id': 1, 'name': 'Beautiful', 'count': 291}, {'id': 2, 'name': 'Confusing', 'count': 32}, {'id': 7, 'name': 'Funny', 'count': 59}, {'id': 9, 'name': 'Ingenious', 'count': 105}, {'id': 21, 'name': 'Unconvincing', 'count': 36}, {'id': 11, 'name': 'Longwinded', 'count': 53}, {'id': 8, 'name': 'Informative', 'count': 380}, {'id': 10, 'name': 'Inspiring', 'count': 1070}, {'id': 22, 'name': 'Fascinating', 'count': 132}, {'id': 24, 'name': 'Persuasive', 'count': 460}, {'id': 23, 'name': 'Jaw-dropping', 'count': 230}, {'id': 26, 'name': 'Obnoxious', 'count': 35}, {'id': 25, 'name': 'OK', 'count': 85}]"

# %% [markdown]
# > Let's check that the function works.

# %%
funny_talks(df.head(1))
# Out:
# {0: 'Do schools kill creativity?'}

# %% [markdown]
# > Let's apply it to every element in the Series.

# %%
funny_talks(df)
# Out:
# {0: 'Do schools kill creativity?',
#  1: 'Averting the climate crisis',
#  2: 'Simplicity sells',
#  3: 'Greening the ghetto',
#  4: "The best stats you've ever seen",
#  5: 'Why we do what we do',
#  6: 'Letting go of God',
#  7: "Behind the design of Seattle's library",
#  8: "Let's teach religion -- all religion -- in schools",
#  9: 'A life of purpose',
#  10: 'My wish: A call for open-source architecture',
#  11: 'My wish: A global day of film',
#  12: 'My wish: Help me stop pandemics',
#  13: 'The radical promise of the multi-touch interface',
#  14: 'One Laptop per Child',
#  15: "An 11-year-old's magical violin",
#  16: 'Improvising on piano, aged 14',
#  17: 'Simple designs to save a life',
#  18: 'Organic design, inspired by nature',
#  19: 'The birth of Wikipedia',
#  20: 'The birth of the open-source learning revolution',
#  21: 'Nerdcore comedy',
#  22: 'Meet the founder of the blog revolution',
#  23: 'Why we love, why we cheat',
#  24: 'Happiness in body and soul',
#  25: 'Chemical scum that dream of distant quasars',
#  26: 'Why the universe seems so strange',
#  27: 'The freakonomics of crack dealing',
#  28: 'Choice, happiness and spaghetti sauce',
#  29: 'The surprising science of happiness',
#  30: 'The paradox of choice',
#  31: 'Meet the future of cancer research',
#  32: 'A roadmap to end aging',
#  33: 'How mobile phones can fight poverty',
#  34: "Invest in Africa's own solutions",
#  35: 'Why we should invest in a free press',
#  36: 'How to rebuild a broken state',
#  37: 'The real future of space exploration',
#  38: 'Why did I ski to the North Pole?',
#  39: 'My wish: Three actions for Africa',
#  40: 'My wish: Manufactured landscapes and green education',
#  41: 'My wish: Three unusual medical inventions',
#  42: 'How juries are fooled by statistics',
#  43: 'Why people believe weird things',
#  44: 'The accelerating power of technology',
#  45: 'How technology evolves',
#  46: 'Fight injustice with raw video',
#  47: '8 secrets of success',
#  48: 'If I controlled the Internet',
#  49: "The killer American diet that's sweeping the planet",
#  50: 'The hidden world of shadow cities',
#  51: 'Global priorities bigger than climate change',
#  52: 'Dreams from endangered cultures',
#  53: 'Photos of endangered cultures',
#  54: 'Is this our final century?',
#  55: 'Progress is not a zero-sum game',
#  56: 'How the "ghost map" helped end a killer disease',
#  57: 'The era of open innovation',
#  58: 'A dance of "Symbiosis"',
#  59: 'Four American characters',
#  60: 'Everyday inventions',
#  61: 'Unleash your creativity in a Fab Lab',
#  62: 'In praise of slowness',
#  63: 'My wish: Rebuilding Rwanda',
#  64: 'My wish: Build the Encyclopedia of Life',
#  65: 'My wish: Let my photographs bear witness',
#  66: 'What separates us from chimpanzees?',
#  67: 'How to get your ideas to spread',
#  68: 'How we discovered DNA',
#  69: 'Visual illusions that show how we (mis)think',
#  70: 'To invent is to give',
#  71: 'The life code that will reshape the future',
#  72: 'Happiness by design',
#  73: 'The route to a sustainable future',
#  74: 'How architecture can connect us',
#  75: 'Great cars are great art',
#  76: 'Singing "What I Want"',
#  77: 'Design is in the details',
#  78: 'Art with wire, sugar, chocolate and string',
#  79: 'A philosophical quest for our biggest problems',
#  80: "Biomimicry's surprising lessons from nature's engineers",
#  81: "Sampling the ocean's DNA",
#  82: 'Software (as) art',
#  83: 'The gentle genius of bonobos',
#  84: 'The story of life in photographs',
#  85: 'The shrimp with a kick!',
#  86: 'Global warming\'s theme song, "Manhattan in January"',
#  87: 'Casting a spell on the cello',
#  88: 'The illusion of consciousness',
#  89: 'How to truly listen',
#  90: 'Cradle to cradle design',
#  91: "The electricity metaphor for the web's future",
#  92: 'A mockingbird remix of TED2006',
#  93: '"Kiteflyer\'s Hill"',
#  94: '"What You\'ve Got"',
#  95: 'Why would God create a tsunami?',
#  96: 'Militant atheism',
#  97: 'A comic sendup of TED2006',
#  98: '"La Vie en Rose"',
#  99: "Technology's long tail",
#  100: 'Cape Breton fiddling in reel time',
#  101: 'The genesis of Google',
#  102: '"Black Men Ski"',
#  103: 'The ghastly tragedy of the suburbs',
#  104: 'Human-centered design',
#  105: 'What squatter cities can teach us',
#  106: 'How brain science will change computing',
#  107: 'Swim with the giant sunfish',
#  108: "How PhotoSynth can connect the world's images",
#  109: 'Salvation (and profit) in greentech',
#  110: 'Want to help Africa? Do business here',
#  111: 'Rethink the desktop with BumpTop',
#  112: 'We can be Buddhas',
#  113: 'A memorial at Ground Zero',
#  114: "Let's rethink America's military strategy",
#  115: 'A string quartet plays "Blue Room"',
#  116: "Tour Microsoft's Virtual Earth",
#  117: 'New insights on poverty',
#  118: "I'm going to the moon. Who's with me?",
#  119: 'Dangerous memes',
#  120: 'The potential of regenerative medicine',
#  121: "The Web's secret stories",
#  122: 'Flip your thinking on AIDS in Africa',
#  123: 'Spore, birth of a game',
#  124: 'The  4 a.m. mystery',
#  125: 'Visualizing the wonder of a living cell',
#  126: 'How to get (a new) hip',
#  127: "Africa's cheetahs versus hippos",
#  128: 'Aid versus trade',
#  129: 'How I built a windmill',
#  130: 'Why invest in Africa',
#  131: 'How to educate leaders? Liberal arts',
#  132: 'Telling stories from Africa',
#  133: 'Patient capitalism',
#  134: '"Thula Mama"',
#  135: '"Woza"',
#  136: 'My journey into movies that matter',
#  137: 'Luke, a new prosthetic arm for soldiers',
#  138: 'The joy of lexicography',
#  139: 'Aid for Africa? No thanks.',
#  140: 'My creations, a new form of life',
#  141: 'What our language habits reveal',
#  142: 'The surprising decline in violence',
#  143: 'An Iraq war movie crowd-sourced from soldiers',
#  144: "The search for humanity's roots",
#  145: 'Designing for simplicity',
#  146: '10 ways the world could end',
#  147: 'A flight on solar wings',
#  148: 'This is Saturn',
#  149: 'My magic moves',
#  150: 'Life at 30,000 feet',
#  151: 'Building "self-aware" robots',
#  152: 'The illustrated woman',
#  153: 'The anthropology of mobile phones',
#  154: '3 clues to understanding your brain',
#  155: 'A commodities exchange for Ethiopia',
#  156: 'How electroshock therapy changed me',
#  157: 'The habits of happiness',
#  158: 'Laws that choke creativity',
#  159: 'Playing with DNA that self-assembles',
#  160: 'A critical look at geoengineering against climate change',
#  161: 'Using biology to rethink the energy challenge',
#  162: 'The case for optimism',
#  163: 'The sticky wonder of gecko feet',
#  164: 'The fractals at the heart of African designs',
#  165: 'Design and destiny',
#  166: 'Beauty, truth and ... physics?',
#  167: 'Winning the oil endgame',
#  168: 'A performance of "Mathemagic"',
#  169: "Why aren't we more compassionate?",
#  170: 'The lost art of letter-writing',
#  171: '5 dangerous things you should let your kids do',
#  172: 'Tales of passion',
#  173: "We're worried about local warming ... in your lap",
#  174: 'The emergent genius of ant colonies',
#  175: 'The mystery box',
#  176: 'Underwater astonishments',
#  177: 'Treat design as art',
#  178: 'A master architect asks, Now what?',
#  179: '"Tembererana"',
#  180: 'Rebuilding a neighborhood with beauty, dignity, hope',
#  181: 'The life-long learner',
#  182: 'The music wars',
#  183: 'An unusual glimpse at celebrity',
#  184: "TED's nonprofit transition",
#  185: 'The idea behind Zipcar (and what comes next)',
#  186: 'A song of the city',
#  187: 'An illustrated journey through Rome',
#  188: "A plant's-eye view",
#  189: 'The new power of collaboration',
#  190: 'The untouchable music of the theremin',
#  191: 'The story of Project Orion',
#  192: 'Building uniqueness',
#  193: 'The Jill and Julia Show',
#  194: 'Juggle and jest',
#  195: 'A parable for Kenya',
#  196: 'Model rocketry',
#  197: 'A preview of the WorldWide Telescope',
#  198: 'A powerful idea about ideas',
#  199: 'On the verge of creating synthetic life',
#  200: '5 predictions, from 1984',
#  201: 'My stroke of insight',
#  202: 'My days as a young rebel',
#  203: 'My wish: Once Upon a School',
#  204: 'My wish: The Charter for Compassion',
#  205: 'My wish: Find the next Einstein in Africa',
#  206: 'My green agenda for architecture',
#  207: 'A look inside the brain in real time',
#  208: 'The call to learn',
#  209: '"M\'Bifo"',
#  210: 'The search for the true face of Leonardo',
#  211: 'Sputnik mania',
#  212: 'A new kind of music video',
#  213: 'Questioning the universe',
#  214: 'New thinking on the climate crisis',
#  215: 'Free or cheap Wii Remote hacks',
#  216: 'Inventing instruments that unlock new music',
#  217: 'The new open-source economics',
#  218: 'World-class health care',
#  219: 'Where does creativity hide?',
#  220: 'Making sense of string theory',
#  221: "CERN's supercollider",
#  222: "Wake up! It's They Might Be Giants!",
#  223: 'The thinking behind 50x15',
#  224: '6 ways mushrooms can save the world',
#  225: 'Can we domesticate germs?',
#  226: 'Juggling as art ... and science',
#  227: 'A thought experiment on the intelligence of crows',
#  228: 'How the news distorts our worldview',
#  229: "What's wrong with what we eat",
#  230: 'The astonishing hidden world of the deep ocean',
#  231: 'Designing objects that tell stories',
#  232: 'Moving sculpture',
#  233: 'A hospital tour in Nigeria',
#  234: 'The "bottom billion"',
#  235: 'Memes and "temes"',
#  236: 'Archeology, animal photography, BBQ ...',
#  237: '"Kounandi"',
#  238: 'The worldwide web of belief and ritual',
#  239: 'The ancestor of language',
#  240: 'The birth of the computer',
#  241: 'Turning powerful stats into art',
#  242: 'Your genes are not your fate',
#  243: 'Robots inspired by cockroach ingenuity',
#  244: 'A mobile fridge for vaccines',
#  245: 'Surprising stats about child carseats',
#  246: 'The transformative power of classical music',
#  247: 'One Laptop per Child, two years on',
#  248: '"Clonie"',
#  249: 'A performance with breath, music, passion',
#  250: "Stephen Hawking's zero g flight",
#  251: 'The story of a girl',
#  252: '"Peace on Earth"',
#  253: 'A hero of the Congo forest',
#  254: 'Animate characters by evolving them',
#  255: 'What happens when you lose everything',
#  256: 'Institutions vs. collaboration',
#  257: '"Mother of Pearl," "If I Had You"',
#  258: "Let's look for life in the outer solar system",
#  259: 'The brain in love',
#  260: 'On technology and faith',
#  261: 'My year of living biblically',
#  262: 'Brain magic',
#  263: 'The new era of positive psychology',
#  264: 'The wonder of Zulu wire art',
#  265: 'On humanity',
#  266: "A dig for humanity's origins",
#  267: 'The web as art',
#  268: 'A tour of modern architecture',
#  269: 'The next 5,000 days of the web',
#  270: 'A computer that works like the brain',
#  271: 'The math and magic of origami',
#  272: 'Blindfold origami and cello',
#  273: 'Shedding light on dark matter',
#  274: 'A family tree for humanity',
#  275: 'How photography connects us',
#  276: 'Close-up card magic with a twist',
#  277: 'Dog-friendly dog training',
#  278: '"The Dog Song"',
#  279: 'Great piano performances, recreated',
#  280: 'Kids can teach themselves',
#  281: 'How I became an activist',
#  282: 'A talking, squawking parrot',
#  283: 'DNA folding, in detail',
#  284: 'Our next giant leap',
#  285: 'The web is more than "better TV"',
#  286: 'What we think we know',
#  287: 'How humans and animals can live together',
#  288: 'How to survive a nuclear attack',
#  289: 'A free digital library',
#  290: 'Life in the deep oceans',
#  291: 'Once upon a time, my mother ...',
#  292: "The camel's hump",
#  293: "What's wrong with school lunches",
#  294: 'The moral roots of liberals and conservatives',
#  295: 'What security means to me',
#  296: 'How to pitch to a VC',
#  297: 'Health and the human mind',
#  298: 'The psychology of evil',
#  299: 'Remember to say thank you',
#  300: 'Playtime with Pleo, your robotic dinosaur friend',
#  301: 'Human nature and the blank slate',
#  302: 'Robots will invade our lives',
#  303: "Things I've learned in my life so far",
#  304: 'Politics and religion are technologies',
#  305: 'The Blur Building and other tech-empowered architecture',
#  306: 'Moving photos of extreme drug-resistant TB',
#  307: 'Are games better than life?',
#  308: 'Lessons from past presidents',
#  309: 'The Web as a city',
#  310: 'Playing invisible turntables',
#  311: 'An 8-dimensional model of the universe',
#  312: 'Design and the Elastic Mind',
#  313: 'On glamour',
#  314: 'Healing through diet',
#  315: 'Aliens, love -- where are they?',
#  316: 'Nature vs. humans',
#  317: 'Flow, the secret to happiness',
#  318: 'The face of AIDS in Africa',
#  319: 'Why do societies collapse?',
#  320: 'A story of mixed emoticons',
#  321: 'Toys and materials from the future',
#  322: 'The story of Ezra',
#  323: 'The balancing act of compassion',
#  324: 'The profound journey of compassion',
#  325: 'Compassion at the dinner table',
#  326: 'Lose your ego, find your compassion',
#  327: 'Expanding your circle of compassion',
#  328: 'The evolution of compassion',
#  329: 'A flight through the ocean',
#  330: 'The power and the danger of online crowds',
#  331: 'Walk the earth ... my 17-year vow of silence',
#  332: 'Tales of creativity and play',
#  333: 'The science of scent',
#  334: 'Science and democracy',
#  335: 'A complicated hero in the war on dictatorship',
#  336: 'The story behind the Mars Rovers',
#  337: 'Tidying up art',
#  338: 'The Long Now',
#  339: 'Fashion and creativity',
#  340: "A tour of Nollywood, Nigeria's booming film industry",
#  341: 'The design of the universe',
#  342: "What I'm worried about, what I'm excited about",
#  343: 'A foie gras parable',
#  344: 'Do the green thing',
#  345: 'The coming neurological epidemic',
#  346: 'The mysterious lives of giant trees',
#  347: 'Life in Second Life',
#  348: 'The future of cars',
#  349: 'Demo: The Orb',
#  350: 'The joyful tradition of mountain music',
#  351: 'The playful search for beauty',
#  352: 'A plea for bees',
#  353: 'My library of human imagination',
#  354: 'Why we make bad decisions',
#  355: 'The price of happiness',
#  356: 'There might just be life on Mars',
#  357: 'The science of sync',
#  358: 'Taking OLPC to Colombia',
#  359: 'The hunt for General Tso',
#  360: 'Play! Experiment! Discover!',
#  361: 'My journey in design',
#  362: 'Digging up dinosaurs',
#  363: 'My dream of a flying car',
#  364: 'Organic algorithms in architecture',
#  365: 'Ways of seeing',
#  366: 'The visual magic of comics',
#  367: 'The art and craft of bread',
#  368: 'What consumers want',
#  369: 'Great design is serious, not solemn',
#  370: 'Design and discovery',
#  371: 'Tools for a better world',
#  372: 'Genomics 101',
#  373: 'The extraordinary power of ordinary people',
#  374: 'Hypersonic sound and other inventions',
#  375: "A theory of Earth's mass extinctions",
#  376: 'Changing my legs - and my mindset',
#  377: 'Solving medical mysteries',
#  378: 'Fiddling in reel time',
#  379: 'A solar energy system that tracks the sun',
#  380: 'Mosquitos, malaria and education',
#  381: 'Your elusive creative genius',
#  382: 'Using design to make ideas new',
#  383: 'Toy tiles that talk to each other',
#  384: 'Our loss of wisdom',
#  385: 'The next species of human',
#  386: 'The El Sistema music revolution',
#  387: "El Sistema's top youth orchestra",
#  388: 'My wish: Protect our oceans',
#  389: 'Join the SETI search',
#  390: 'How Benjamin Button got his face',
#  391: 'Seas of plastic',
#  392: "A dive into the reef's Twilight Zone",
#  393: 'My underground art explorations',
#  394: 'The voices of Twitter users',
#  395: 'Why not make video games for girls?',
#  396: 'How to restore a rainforest',
#  397: 'Conserving the canopy',
#  398: 'Learning from dirty jobs',
#  399: 'Piano jazz that rocks',
#  400: '3 ways good design makes you happy',
#  401: 'Meet the SixthSense interaction',
#  402: 'My 12 pairs of legs',
#  403: 'Play is more than just fun',
#  404: 'The next web',
#  405: 'Cute, sexy, sweet, funny',
#  406: 'Our buggy moral code',
#  407: 'My obsession with objects and the stories they tell',
#  408: 'What is retro-futurism?',
#  409: 'How to grow fresh air',
#  410: 'High-altitude wind energy from kites!',
#  411: 'An escape from poverty',
#  412: 'Cool tricks your phone can do',
#  413: 'The difference between winning and succeeding',
#  414: 'The jungle search for viruses',
#  415: 'Poetry of youth and age',
#  416: 'Can design save newspapers?',
#  417: 'Extreme wingsuit flying',
#  418: 'The Airstream, restyled',
#  419: 'Military robots and the future of war',
#  420: 'Scenes from "My Architect"',
#  421: 'A prediction for the future of Iran',
#  422: 'How bacteria "talk"',
#  423: 'A theory of everything',
#  424: 'Our antisocial phone tricks',
#  425: 'A new ecosystem for electric cars',
#  426: 'To upgrade is human',
#  427: 'Stunning data visualization in the AlloSphere',
#  428: 'Smash fear, learn anything',
#  429: '9 life lessons from rock climbing',
#  430: 'The beautiful math of coral',
#  431: 'Rethinking the way we sit down',
#  432: 'Reporting crisis via texting',
#  433: 'Does racism affect how you vote?',
#  434: 'Comics of bygone New York',
#  435: 'How ideas trump crises',
#  436: 'Growing evidence of brain plasticity',
#  437: 'A one-woman global village',
#  438: 'Lessons from the 1918 flu',
#  439: 'What went wrong at the LHC',
#  440: 'The mathematics of war',
#  441: 'Teach arts and sciences together',
#  442: 'Anti-gravity sculpture',
#  443: 'What comes after An Inconvenient Truth?',
#  444: 'We need to feed the whole world',
#  445: 'The tribes we lead',
#  446: 'Chaos and harmony on piano',
#  447: 'Insights on HIV, in stunning data visuals',
#  448: "Ideas for India's future",
#  449: 'A full-band beatbox',
#  450: 'The business logic of sustainability',
#  451: 'Are we in control of our own decisions?',
#  452: "10 things you didn't know about orgasm",
#  453: 'Could a Saturn moon harbor life?',
#  454: 'A supercharged motorcycle design',
#  455: "Don't eat the marshmallow!",
#  456: "The world's English mania",
#  457: 'A passionate, personal case for education',
#  458: "Why we're storing billions of seeds",
#  459: 'Playing "Pink Noise" on guitar',
#  460: 'A call to reinvent liberal arts education',
#  461: 'A university for the coming singularity',
#  462: 'A wide-angle view of fragile Earth',
#  463: 'Odes to vice and consequences',
#  464: 'The world in 2200',
#  465: 'A plug for smart power outlets',
#  466: 'Eco-friendly drywall',
#  467: 'Happiness and its surprises',
#  468: "Learning from the gecko's tail",
#  469: 'Success is a continuous journey',
#  470: 'Life in Biosphere 2',
#  471: 'How social media can make history',
#  472: 'How cults rewire the brain',
#  473: "Surgery's past, present and robotic future",
#  474: 'An electrifying organ performance',
#  475: 'The psychology of time',
#  476: 'New rules for rebuilding a broken nation',
#  477: 'You are the future of philanthropy',
#  478: 'My trek to the South Pole',
#  479: 'Teach statistics before calculus!',
#  480: 'Life lessons through tinkering',
#  481: '17 words of architectural inspiration',
#  482: 'The design genius of Charles + Ray Eames',
#  483: '3 ways the brain creates meaning',
#  484: 'Escaping the Khmer Rouge',
#  485: 'A next-gen cure for killer infections',
#  486: "4 environmental 'heresies'",
#  487: 'Playing with space and light',
#  488: 'A better way to harvest bone marrow',
#  489: 'Exploring the mind of a killer',
#  490: 'Skin color is an illusion',
#  491: 'Wiring a web for global good',
#  492: 'A kinder, gentler philosophy of success',
#  493: 'Art that looks back at you',
#  494: 'I believe we evolved from aquatic apes',
#  495: 'Hold your breath for micro-sculpture',
#  496: 'How to make filthy water drinkable',
#  497: 'Why the world needs charter cities',
#  498: 'Biomimicry in action',
#  499: 'The music of a war child',
#  500: 'The puzzle of motivation',
#  501: 'A demo of wireless electricity',
#  502: 'Let my dataset change your mindset',
#  503: 'A multimedia theatrical adventure',
#  504: 'One seed at a time, protecting the future of food',
#  505: 'Adjustable liquid-filled eyeglasses',
#  506: 'Post-crash, investing in a better world',
#  507: 'Making sound visible through cymatics',
#  508: 'A leap from the edge of space',
#  509: 'Time-lapse proof of extreme ice loss',
#  510: 'How I swam the North Pole',
#  511: "How we read each other's minds",
#  512: 'Hypnotic South Asian improv music',
#  513: 'How global crime networks work',
#  514: '3 warp-speed architecture tales',
#  515: 'An inventory of the invisible',
#  516: 'What hallucination reveals about our minds',
#  517: '"Wait It Out"',
#  518: 'The Web as random acts of kindness',
#  519: 'How the Net aids dictatorships',
#  520: 'How I harnessed the wind',
#  521: 'Photographs of secret sites',
#  522: 'A third way to think about aid',
#  523: 'Mapping the future of countries',
#  524: 'Designers -- think big!',
#  525: "Let's revive the Golden Rule",
#  526: 'How spectroscopy could reveal alien life',
#  527: 'The power of time off',
#  528: 'How food shapes our cities',
#  529: 'Tribal leadership',
#  530: 'The danger of a single story',
#  531: 'Optical illusions show how we see',
#  532: 'Claim your "manspace"',
#  533: 'New York -- before the City',
#  534: 'Robots that "show emotion"',
#  535: 'Life lessons from an ad man',
#  536: 'A brain in a supercomputer',
#  537: 'The 4 ways sound affects us',
#  538: 'The post-crisis consumer',
#  539: 'Animating a photo-real digital face',
#  540: 'Lead like the great conductors',
#  541: '1.3m reasons to re-invent the syringe',
#  542: 'Navigating our global future',
#  543: 'A new way to explain explanation',
#  544: 'Architecture that repairs itself?',
#  545: 'The year I was homeless',
#  546: "Symmetry, reality's riddle",
#  547: 'The modern euphonium',
#  548: 'How the Internet enables intimacy',
#  549: 'The refugees of boom-and-bust',
#  550: 'The science behind a climate headline',
#  551: 'Photographing the landscape of oil',
#  552: 'The surprising spread of Idol TV',
#  553: 'The thrilling potential of SixthSense technology',
#  554: 'Science-inspired design',
#  555: "Learning from leadership's missing manual",
#  556: 'East vs. West -- the myths that mystify',
#  557: 'Learn to use the 13th-century astrolabe',
#  558: "Asia's rise -- how and when",
#  559: 'Transition to a world without oil',
#  560: 'Turning dunes into architecture',
#  561: 'Dance to change the world',
#  562: 'Why nations should pursue soft power',
#  563: 'Global ethic vs. national interest',
#  564: 'The hunt for a supermassive black hole',
#  565: 'The ancient ingenuity of water harvesting',
#  566: 'The art of puzzles',
#  567: 'The fight against sex slavery',
#  568: 'A one-man world summit',
#  569: 'The art of the interview',
#  570: 'How low-cost eye care can be world-class',
#  571: 'Pop culture in the Arab world',
#  572: 'The intricate economics of terrorism',
#  573: 'Photographing the hidden story',
#  574: 'How to make a splash in social media',
#  575: 'Dragonflies that fly across oceans',
#  576: 'Metaphorically speaking',
#  577: 'A new way to fight corruption',
#  578: "Fusion is energy's future",
#  579: 'My message of peace from Pakistan',
#  580: "What's the right thing to do?",
#  581: 'Engineering a better life for all',
#  582: 'My solar-powered adventure',
#  583: 'The neurons that shaped civilization',
#  584: 'Exposing the invisible',
#  585: 'How to live to be 100+',
#  586: 'The real danger lurking in the water',
#  587: 'An all-star set',
#  588: 'Really achieving your childhood dreams',
#  589: 'The uniqueness of humans',
#  590: "What Bernie Madoff couldn't steal from me",
#  591: 'How we rescued the "dancing" bears"',
#  592: 'Kids, take charge',
#  593: 'Making maps to fight disaster, build economies',
#  594: 'Stories of Haiti',
#  595: 'All things are Moleeds',
#  596: 'How I held my breath for 17 minutes',
#  597: '10 young Indian artists to watch',
#  598: 'Growing new organs',
#  599: 'Rhythm is everything, everywhere',
#  600: 'Growing up in the universe',
#  601: 'What teachers make',
#  602: 'Your health depends on where you live',
#  603: 'Building a theater that remakes itself',
#  604: 'Embrace your inner girl',
#  605: 'A warm embrace that saves lives',
#  606: 'Weird, or just different?',
#  607: 'The fringe benefits of failure',
#  608: 'Solving social problems with a nudge',
#  609: 'The big idea my brother inspired',
#  610: 'A lab the size of a postage stamp',
#  611: 'A new strategy in the war on cancer',
#  612: 'The painter and the pendulum',
#  613: 'How to expose the corrupt',
#  614: 'Teach every child about food',
#  615: 'Augmented-reality maps',
#  616: 'The next age of government',
#  617: 'The opportunity of adversity',
#  618: 'Innovating to zero!',
#  619: "Technology's epic story",
#  620: 'Four ways to fix a broken legal system',
#  621: 'The wireless future of medicine',
#  622: 'The world needs all kinds of minds',
#  623: 'How brains learn to see',
#  624: 'My 5 lives as an artist',
#  625: 'Watch me play ... the audience!',
#  626: 'The riddle of experience vs. memory',
#  627: 'The rise of cricket, the rise of India',
#  628: 'Is Pivot a turning point for web exploration?',
#  629: 'Physics is fun to imagine',
#  630: 'Before Avatar ... a curious boy',
#  631: 'In the Internet age, dance evolves ...',
#  632: 'Plug into your hard-wired happiness',
#  633: 'The year open data went worldwide',
#  634: 'Take Turns',
#  635: 'How I fell in love with a fish',
#  636: 'The magic of the placebo',
#  637: 'Do what you love (no excuses!)',
#  638: 'Suspended animation is within our grasp',
#  639: 'Take health care off the mainframe',
#  640: 'Parrots, the universe and everything',
#  641: 'Gaming can make a better world',
#  642: 'Medical miracle on Everest',
#  643: 'We are the stories we tell ourselves',
#  644: 'Science can answer moral questions',
#  645: 'The fight to end rare-animal trafficking in Brazil',
#  646: "Let's simplify legal jargon!",
#  647: 'Why we need to go back to Mars',
#  648: 'Music is medicine, music is sanity',
#  649: 'Why I do theater',
#  650: 'How to combat modern slavery',
#  651: 'Teaching one child at a time',
#  652: 'And now, the real news',
#  653: 'How to start a movement',
#  654: 'What adults can learn from kids',
#  655: 'When games invade real life',
#  656: "Sex, drugs and HIV -- let's get rational",
#  657: 'The emotion behind invention',
#  658: 'My seven species of robot -- and how we created them',
#  659: 'Every pollen grain has a story',
#  660: 'Singing old poems to life',
#  661: 'The danger of science denial',
#  662: 'Photos that changed the world',
#  663: 'The tradeoffs of building green',
#  664: 'How art gives shape to cultural change',
#  665: 'A choir as big as the Internet',
#  666: 'Glowing life in an underwater world',
#  667: 'Homeopathy, quackery and fraud',
#  668: 'Bio-lab on a microchip',
#  669: 'Build a tower, build a team',
#  670: 'Political change with pen and paper',
#  671: 'Radical women, embracing tradition',
#  672: 'Computing a theory of all knowledge',
#  673: "Why I'm rowing across the Pacific",
#  674: 'Toward a science of simplicity',
#  675: 'Lies, damned lies and statistics (about TEDTalks)',
#  676: 'Social experiments to fight poverty',
#  677: 'How great leaders inspire action',
#  678: 'How we wrecked the ocean',
#  679: "India's hidden hotbeds of invention",
#  680: '"Love Is a Loaded Pistol"',
#  681: 'The hidden influence of social networks',
#  682: 'Could this laser zap malaria?',
#  683: 'Glimpses of a pristine ocean',
#  684: 'Math class needs a makeover',
#  685: 'It\'s time for "The Talk"',
#  686: 'Why believe in others',
#  687: 'Can we eat to starve cancer?',
#  688: "Why I'm a weekday vegetarian",
#  689: 'Pay attention to penguins',
#  690: 'Planning for the end of oil',
#  691: 'Watch me unveil "synthetic life"',
#  692: 'Bring on the learning revolution!',
#  693: "Lessons from fashion's free culture",
#  694: 'Inside a school for suicide bombers',
#  695: 'HIV and flu -- the vaccine strategy',
#  696: 'Songs of secrets and city lights',
#  697: 'Re-examining the remix',
#  698: 'Pointing to the future of UI',
#  699: "The ocean's glory -- and horror",
#  700: 'The case for anonymity online',
#  701: 'Why we need the explorers',
#  702: 'How to engineer a viral music video',
#  703: 'The lost art of democratic debate',
#  704: 'How poachers became caretakers',
#  705: 'Sweat the small stuff',
#  706: 'Debate: Does the world need nuclear energy?',
#  707: 'How architecture helped music evolve',
#  708: 'The pattern behind self-deception',
#  709: 'How YouTube thinks about copyright',
#  710: 'The intriguing sound of marine mammals',
#  711: "Let's raise kids to be entrepreneurs",
#  712: 'Fighting cancer with dance',
#  713: 'Measuring what makes life worthwhile',
#  714: 'Intricate beauty by design',
#  715: 'Education innovation in the slums',
#  716: 'A second opinion on developmental disorders',
#  717: 'Legos for grownups',
#  718: 'How cognitive surplus will change the world',
#  719: 'Retrofitting suburbia',
#  720: 'Hidden toxins in the fish we eat',
#  721: 'A 3D atlas of the universe',
#  722: "Don't build your home, grow it!",
#  723: 'Fractals and the art of roughness',
#  724: 'Obesity + hunger = 1 global food issue',
#  725: 'Life science in prison',
#  726: 'Global population growth, box by box',
#  727: "The oil spill's unseen villains -- and victims",
#  728: 'When ideas have sex',
#  729: 'Listening to global voices',
#  730: 'The politics of fiction',
#  731: 'Why the world needs WikiLeaks',
#  732: 'Superheroes inspired by Islam',
#  733: 'How we found hundreds of potential Earth-like planets',
#  734: 'A headset that reads your brainwaves',
#  735: 'The bio-future of joint replacement',
#  736: 'The art of choosing',
#  737: "The oil spill's toxic trade-off",
#  738: 'What matters more than your talents',
#  739: 'Wiring an interactive ocean',
#  740: 'A monkey economy as irrational as ours',
#  741: 'My mind-shifting Everest swim',
#  742: 'How big brands can help save biodiversity',
#  743: "Our century's greatest injustice",
#  744: 'The case for same-sex marriage',
#  745: 'Meet Milo, the virtual boy',
#  746: 'The Axis of Evil Middle East Comedy Tour',
#  747: 'Did you hear the one about the Iranian-American?',
#  748: 'The game layer on top of the world',
#  749: 'The beauty of data visualization',
#  750: 'Inside an Antarctic time machine',
#  751: 'The empathic civilization',
#  752: 'Learning from Sherman the shark',
#  753: 'The political chemistry of oil',
#  754: 'What physics taught me about marketing',
#  755: 'The Happy Planet Index',
#  756: 'Let the environment guide our development',
#  757: 'The technology of the heart',
#  758: 'Keep your goals to yourself',
#  759: "The world's oldest living things",
#  760: 'The child-driven education',
#  761: 'Art of substance and absence',
#  762: 'An independent diplomat',
#  763: 'Why the live arts matter',
#  764: 'This is broken',
#  765: 'Discovering ancient climates in oceans and ice',
#  766: 'How web video powers global innovation',
#  767: 'Our natural sleep cycle is nothing like what we do now',
#  768: 'How social networks predict epidemics',
#  769: 'Hurdy-gurdy for beginners',
#  770: 'How pig parts make the world turn',
#  771: 'Where good ideas come from',
#  772: 'Mothers helping mothers fight HIV',
#  773: 'Why I am an HIV/AIDS activist',
#  774: 'The shape-shifting future of the mobile phone',
#  775: 'Shh! Sound health in 8 steps',
#  776: 'The early birdwatchers',
#  777: 'The quantified self',
#  778: 'I am my connectome',
#  779: 'Bringing peace to the minds of Afghanistan',
#  780: 'How Mr. Condom made Thailand a better place for life and love',
#  781: 'Are mushrooms the new plastic?',
#  782: 'An economic reality check',
#  783: 'Tagging tuna in the deep ocean',
#  784: "The good news of the decade? We're winning the war against child mortality",
#  785: 'The best gift I ever survived',
#  786: 'The roots of plant intelligence',
#  787: 'What nonprofits can learn from Coca-Cola',
#  788: "Haiti's disaster of engineering",
#  789: 'The art of the eco-mindshift',
#  790: 'My web playroom',
#  791: 'A message to gay teens: It gets better',
#  792: 'Poverty, money -- and love',
#  793: 'The brain in your gut',
#  794: 'Tough truths about plastic pollution',
#  795: 'The power of cartoons',
#  796: '"(Nothing But) Flowers" with string quartet',
#  797: 'Breakthrough designs for ultra-low-cost products',
#  798: 'Global power shifts',
#  799: "Sustainable seafood? Let's get smart",
#  800: 'Natural pest control ... using bugs!',
#  801: 'Glorious visions in animation and performance',
#  802: '7 ways games reward the brain',
#  803: 'E-voting without fraud',
#  804: 'Saving the ocean one island at a time',
#  805: 'Re-engineering the brain',
#  806: 'A one-man orchestra of the imagination',
#  807: 'Teaching design for change',
#  808: 'The path to ending ethnic conflicts',
#  809: "America's native prisoners of war",
#  810: 'Making global labor fair',
#  811: 'Simplifying complexity',
#  812: 'Teaching kids real math with computers',
#  813: 'A Darwinian theory of beauty',
#  814: 'What a bike ride can teach you',
#  815: 'My green school dream',
#  816: 'Making law on the high seas',
#  817: 'Protecting the brain against concussion',
#  818: 'Women, wartime and the dream of peace',
#  819: "Why work doesn't happen at work",
#  820: 'Creative houses from reclaimed stuff',
#  821: "What's wrong with our food system",
#  822: 'The walk from "no" to "yes"',
#  823: 'Why not eat insects?',
#  824: 'How I taught rats to sniff out land mines',
#  825: 'A vision for sustainable restaurants',
#  826: "A feminine response to Iceland's financial crash",
#  827: 'A call to men',
#  828: 'A police chief with a difference',
#  829: 'New data on the rise of women',
#  830: 'How to learn? From mistakes',
#  831: "Let's talk parenting taboos",
#  832: 'The case for collaborative consumption',
#  833: 'Changing education paradigms',
#  834: 'Life lessons from big cats',
#  835: 'Why we have too few women leaders',
#  836: '3 stories of local eco-entrepreneurship',
#  837: 'The power of vulnerability',
#  838: 'Using our practical wisdom',
#  839: 'How to succeed? Get more sleep',
#  840: 'On reading the Koran',
#  841: 'Your brain on improv',
#  842: "A test that finds 3x more breast tumors, and why it's not available to you",
#  843: "The 3 A's of awesome",
#  844: 'A realistic vision for world peace',
#  845: 'We are all cyborgs now',
#  846: 'How I built a toaster -- from scratch',
#  847: 'Take "the Other" to lunch',
#  848: 'Gaming to re-engage boys in learning',
#  849: 'Addicted to risk',
#  850: 'Singing after a double lung transplant',
#  851: 'The economic injustice of plastic',
#  852: 'Visualizing the medical data explosion',
#  853: 'Silicon-based comedy',
#  854: 'Understanding the rise of China',
#  855: "It's time to redesign medical data",
#  856: 'Drawing on humor for change',
#  857: 'Know thyself, with a brain scanner',
#  858: 'The council of dads',
#  859: "Reviving New York's rivers -- with oysters!",
#  860: 'We are makers',
#  861: 'Social media and the end of gender',
#  862: 'Are we born to run?',
#  863: 'Poems of war, peace, women, power',
#  864: 'How to make work-life balance work',
#  865: 'The rise of personal robots',
#  866: 'Mother and daughter doctor-heroes',
#  867: "Using nature's genius in architecture",
#  868: "A whistleblower you haven't heard",
#  869: 'Reconnecting with compassion',
#  870: 'The linguistic genius of babies',
#  871: 'Inspiring a life of immersion',
#  872: 'The future of business is the "mesh"',
#  873: 'On being a woman and a diplomat',
#  874: 'How to use experts -- and when not to',
#  875: "Saving faces: A facial surgeon's craft",
#  876: "Curating humanity's heritage",
#  877: 'Understanding cancer through proteomics',
#  878: 'A modern take on piano, violin, cello',
#  879: 'A historic moment in the Arab world',
#  880: 'My wish: Use art to turn the world inside out',
#  881: 'Inside the Egyptian revolution',
#  882: 'How state budgets are breaking US schools',
#  883: 'Printing a human kidney',
#  884: "This isn't her mother's feminism",
#  885: "Let's use video to reinvent education",
#  886: 'The birth of a word',
#  887: 'How to keep rivers and streams flowing',
#  888: 'The social animal',
#  889: 'The sound the universe makes',
#  890: 'A life lesson from a volunteer firefighter',
#  891: 'Why light needs darkness',
#  892: 'If I should have a daughter ...',
#  893: 'The magic washing machine',
#  894: "Evolution's gift of play, from bonobo apes to humans",
#  895: "It's time to question bio-engineering",
#  896: 'Human exoskeletons -- for war and healing',
#  897: 'Singing the primal mystery',
#  898: "Don't insist on English!",
#  899: 'Cracking Stuxnet, a 21st-century cyber weapon',
#  900: 'The genius puppetry behind War Horse',
#  901: "Google's driverless car",
#  902: 'A virtual choir 2,000 voices strong',
#  903: 'Hands-on science with squishy circuits',
#  904: 'Listen, learn ... then lead',
#  905: 'Everyday compassion at Google',
#  906: 'The greatest TED Talk ever sold',
#  907: 'The invention that unlocked a locked-in artist',
#  908: 'Looking past limits',
#  909: 'A song inspired by the ocean',
#  910: 'The history of our world in 18 minutes',
#  911: 'The antidote to apathy',
#  912: 'Remaking my voice',
#  913: 'Open-sourced blueprints for civilization',
#  914: 'Transplant cells, not organs',
#  915: 'A radical experiment in empathy',
#  916: 'On being wrong',
#  917: 'Teaching with the World Peace Game',
#  918: 'What it takes to do extreme astrophysics',
#  919: '3 things I learned while my plane crashed',
#  920: 'Are we ready for neo-evolution?',
#  921: 'The security mirage',
#  922: 'Using nature to grow batteries',
#  923: 'A next-generation digital book',
#  924: 'Turning trash into toys for learning',
#  925: 'Beware online "filter bubbles"',
#  926: 'The mothers who found forgiveness, friendship',
#  927: 'Architecture that senses and responds',
#  928: 'Grow your own clothes',
#  929: 'Distant time and the hint of a multiverse',
#  930: 'The hidden beauty of pollination',
#  931: 'Animal tales from icy wonderlands',
#  932: 'Silk, the ancient material of the future',
#  933: 'The hidden power of smiling',
#  934: 'Building a museum of museums on the web',
#  935: 'My friend Richard Feynman',
#  936: 'A light switch for neurons',
#  937: 'Building the Seed Cathedral',
#  938: 'The mystery of chronic pain',
#  939: 'The weird, wonderful world of bioluminescence',
#  940: 'How to tie your shoes',
#  941: 'Gotta share!',
#  942: 'Visualizing ourselves ... with crowd-sourced data',
#  943: "How we'll stop polio for good",
#  944: 'Art in exile',
#  945: 'Faith versus tradition in Islam',
#  946: 'On violin and cello, "Passacaglia"',
#  947: 'Authentic creativity vs. karaoke culture',
#  948: 'Making a car for blind drivers',
#  949: '7 rules for making more happiness',
#  950: 'Making sense of a visible quantum object',
#  951: 'Wearing nothing new',
#  952: 'We need a "moral operating system"',
#  953: 'Building a dinosaur from a chicken',
#  954: 'Taking imagination seriously',
#  955: "The world's first charter city?",
#  956: 'Is anatomy destiny?',
#  957: 'Break the silence for suicide attempt survivors',
#  958: "Medicine's future? There's an app for that",
#  959: 'How I became 100 artists',
#  960: 'A manifesto for play, for Bulgaria and beyond',
#  961: 'Haunting photos of polar ice',
#  962: 'This is beatjazz',
#  963: 'A cello with many voices',
#  964: 'A future beyond traffic gridlock',
#  965: 'Different ways of knowing',
#  966: 'A circle of caring',
#  967: 'A history of the universe in sound',
#  968: 'On being just crazy enough',
#  969: 'A civil response to violence',
#  970: 'A Rosetta Stone for a lost language',
#  971: 'Meet e-Patient Dave',
#  972: 'Building a park in the sky',
#  973: 'Try something new for 30 days',
#  974: 'Cooking as never seen before',
#  975: 'The beautiful tricks of flowers',
#  976: "Don't take consciousness for granted",
#  977: 'Caring for engineered tissue',
#  978: "Let's take back the Internet!",
#  979: 'A global culture to fight extremism',
#  980: 'Trial, error and the God complex',
#  981: 'See Yemen through my eyes',
#  982: 'Fighting viruses, defending the net',
#  983: 'Embracing otherness, embracing myself',
#  984: 'How algorithms shape our world',
#  985: 'A robot that flies like a bird',
#  986: 'Time to end the war in Afghanistan',
#  987: 'The surprising math of cities and corporations',
#  988: 'The origins of pleasure',
#  989: 'Ending hunger now',
#  990: '5 ways to listen better',
#  991: 'After your final status update',
#  992: 'Wireless data from every light bulb',
#  993: 'How language transformed humanity',
#  994: 'Are we filtering the wrong microbes?',
#  995: 'The demise of guys?',
#  996: 'Suddenly, my body',
#  997: 'The shareable future of cities',
#  998: 'The great penguin rescue',
#  999: 'One day of peace',
#  ...}

# %% [markdown]
# > Do check for `missing values`.

# %%
df.isna().sum()
# Out:
# comments              0
# description           0
# duration              0
# event                 0
# film_date             0
# languages             0
# main_speaker          0
# name                  0
# num_speaker           0
# published_date        0
# ratings               0
# related_talks         0
# speaker_occupation    6
# tags                  0
# title                 0
# url                   0
# views                 0
# comments_per_view     0
# views_per_comment     0
# delay                 0
# talk_year             0
# rating_count          0
# funny_count           0
# contain_funny         0
# dtype: int64

# %% [markdown]
# ##### Now, let's calculate the percentage of ratings that are funny

# %%
df['pct_funny'] = df.eval('funny_count / rating_count')

# %% [markdown]
# > Let's do some "gut check" here that this calculation makes sense by examining the occupations of the funniest talks

# %%
(
    df
    [['speaker_occupation', 'pct_funny']]
    .sort_values(
        by = 'pct_funny', 
        ascending  = False
    )
)
# Out:
#                speaker_occupation  pct_funny
# 685   Actor, comedian, playwright   0.702076
# 1398                     Comedian   0.669927
# 747                      Comedian   0.630677
# 173                      Investor   0.629662
# 2114          Comedian and writer   0.625182
# ...                           ...        ...
# 2437       Environmental engineer   0.000000
# 788             Building activist   0.000000
# 808      Ethnic conflicts scholar   0.000000
# 810         Labor-rights activist   0.000000
# 2549                Game designer   0.000000
#
# [2550 rows x 2 columns]

# %% [markdown]
# > Let's examine the occupations of the least funny talks.

# %%
(
    df
    [['speaker_occupation', 'pct_funny']]
    .sort_values(
        by = 'pct_funny', 
        ascending  = True
    )
)
# Out:
#                speaker_occupation  pct_funny
# 2549                Game designer   0.000000
# 1612                    Biologist   0.000000
# 612                      Sculptor   0.000000
# 998                Penguin expert   0.000000
# 593                      Engineer   0.000000
# ...                           ...        ...
# 2114          Comedian and writer   0.625182
# 173                      Investor   0.629662
# 747                      Comedian   0.630677
# 1398                     Comedian   0.669927
# 685   Actor, comedian, playwright   0.702076
#
# [2550 rows x 2 columns]

# %% [markdown]
# ### Question 9. It would be funny (pun inteded here) to analyze the funny rate by occupation :) Let's calculate the mean funny rate for each job.

# %%
(
    df
    .groupby('speaker_occupation')
    .agg(
        mean = ('pct_funny', 'mean')
    )
)
# Out:
#                                                  mean
# speaker_occupation
#  Chairman of the Cordoba Initiative          0.000000
#  Child protection leader, activist, author   0.002421
#  Robotics engineer                           0.007353
#  Space physicist                             0.015447
# 3D printer                                   0.007789
# ...                                               ...
# e-Patient                                    0.014374
# inventor, engineer                           0.011745
# medical inventor                             0.002993
# photographer + visual artist                 0.236461
# physicist                                    0.017105
#
# [1458 rows x 1 columns]

# %% [markdown]
# ##### Note that most of the occupations have a sample size of 1

# %%
(
    df
    .groupby('speaker_occupation')
    .agg(
        count = ('speaker_occupation', 'count'), 
        mean = ('pct_funny', 'mean')
    )
)
# Out:
#                                              count      mean
# speaker_occupation
#  Chairman of the Cordoba Initiative              1  0.000000
#  Child protection leader, activist, author       1  0.002421
#  Robotics engineer                               1  0.007353
#  Space physicist                                 1  0.015447
# 3D printer                                       1  0.007789
# ...                                            ...       ...
# e-Patient                                        1  0.014374
# inventor, engineer                               1  0.011745
# medical inventor                                 1  0.002993
# photographer + visual artist                     1  0.236461
# physicist                                        1  0.017105
#
# [1458 rows x 2 columns]

# %% [markdown]
# ### Question 10. Let's start looking at `occupations` that are well-represented in the dataset. Let's count how many times each job appears

# %% [markdown]
# ##### `value_counts()` outputs a pandas Series, thus we can use pandas to manipulate the output

# %%
occupation_count = \
(
    df
    ['speaker_occupation']
    .value_counts()
)
occupation_count
# Out:
# Writer                  45
# Artist                  34
# Designer                34
# Journalist              33
# Entrepreneur            31
#                         ..
# Science author           1
# Pro snowboarder          1
# Artist, urban farmer     1
# Entrepreneur, author     1
#  Robotics engineer       1
# Name: speaker_occupation, Length: 1458, dtype: int64

# %% [markdown]
# ##### Let's take a look at jobs which appear at least 5 times

# %%
occupation_count[occupation_count >= 5]
# Out:
# Writer                        45
# Artist                        34
# Designer                      34
# Journalist                    33
# Entrepreneur                  31
#                               ..
# Data scientist                 5
# Musician, activist             5
# Social Media Theorist          5
# Environmentalist, futurist     5
# Chef                           5
# Name: speaker_occupation, Length: 68, dtype: int64

# %% [markdown]
# > Let's save the index of this Series

# %%
occupation_filtered = \
(
    occupation_count
    [occupation_count >= 5]
    .index
)

# %% [markdown]
# ##### Now, re-analyze the funny rate by occupation (for top jobs only)

# %% [markdown]
# > Let's filter DataFrame to include only those jobs.

# %%
filtered_df =\
(
    df
    [
        df['speaker_occupation']
        .isin(occupation_filtered)
    ]
)

filtered_df
# Out:
#       comments                                        description  duration  \
# 1          265  With the same humor and humanity he exuded in ...       977
# 4          593  You've never seen data presented like this. Wi...      1190
# 7           46  Architect Joshua Prince-Ramus takes the audien...      1198
# 11          55  Jehane Noujaim unveils her 2006 TED Prize wish...      1538
# 14          99  Nicholas Negroponte, founder of the MIT Media ...      1057
# ...        ...                                                ...       ...
# 2539        10  Forget quinoa. Meet fonio, an ancient "miracle...       934
# 2541        12  Physics doesn't just happen in a fancy lab -- ...       957
# 2542         3  In the century-old statues that occupy Cape To...       795
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2549         8  With more than half of the world population li...       519
#
#                event                     film_date  languages  \
# 1            TED2006 1970-01-01 00:00:01.140825600         43
# 4            TED2006 1970-01-01 00:00:01.140566400         48
# 7            TED2006 1970-01-01 00:00:01.140652800         19
# 11           TED2006 1970-01-01 00:00:01.140912000         20
# 14           TED2006 1970-01-01 00:00:01.140652800         25
# ...              ...                           ...        ...
# 2539         TED2017 1970-01-01 00:00:01.503792000          2
# 2541  TEDxManchester 1970-01-01 00:00:01.487462400          2
# 2542  TEDGlobal 2017 1970-01-01 00:00:01.503792000          1
# 2545         TED2017 1970-01-01 00:00:01.496707200          4
# 2549         TED2017 1970-01-01 00:00:01.492992000          1
#
#              main_speaker                                               name  \
# 1                 Al Gore               Al Gore: Averting the climate crisis
# 4            Hans Rosling      Hans Rosling: The best stats you've ever seen
# 7     Joshua Prince-Ramus  Joshua Prince-Ramus: Behind the design of Seat...
# 11         Jehane Noujaim      Jehane Noujaim: My wish: A global day of film
# 14    Nicholas Negroponte          Nicholas Negroponte: One Laptop per Child
# ...                   ...                                                ...
# 2539         Pierre Thiam  Pierre Thiam: A forgotten ancient grain that c...
# 2541        Helen Czerski  Helen Czerski: The fascinating physics of ever...
# 2542   Sethembile Msezane  Sethembile Msezane: Living sculptures that sta...
# 2545     Duarte Geraldino  Duarte Geraldino: What we're missing in the de...
# 2549    Karoliina Korppoo  Karoliina Korppoo: How a video game might help...
#
#       num_speaker      published_date  ...  \
# 1               1 2006-06-27 00:11:00  ...
# 4               1 2006-06-27 20:38:00  ...
# 7               1 2006-07-10 00:11:00  ...
# 11              1 2006-07-25 00:11:00  ...
# 14              1 2006-08-01 00:11:00  ...
# ...           ...                 ...  ...
# 2539            1 2017-09-13 14:45:42  ...
# 2541            1 2017-09-14 20:00:02  ...
# 2542            1 2017-09-15 15:08:13  ...
# 2545            1 2017-09-19 20:00:16  ...
# 2549            1 2017-09-22 15:00:22  ...
#
#                                                     url     views  \
# 1     https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 4     https://www.ted.com/talks/hans_rosling_shows_t...  12005869
# 7     https://www.ted.com/talks/joshua_prince_ramus_...    967741
# 11    https://www.ted.com/talks/jehane_noujaim_inspi...    387877
# 14    https://www.ted.com/talks/nicholas_negroponte_...    358304
# ...                                                 ...       ...
# 2539  https://www.ted.com/talks/pierre_thiam_a_forgo...    527314
# 2541  https://www.ted.com/talks/helen_czerski_fun_ho...    656791
# 2542  https://www.ted.com/talks/sethembile_msezane_l...    542088
# 2545  https://www.ted.com/talks/duarte_geraldino_wha...    450430
# 2549  https://www.ted.com/talks/karoliina_korppoo_ho...    391721
#
#      comments_per_view views_per_comment     delay talk_year  rating_count  \
# 1             0.000083      12077.433962  10541460      2006          2936
# 4             0.000049      20245.984823  10874280      2006         25620
# 7             0.000048      21037.847826  11837460      2006          1024
# 11            0.000142       7052.309091  12874260      2006           592
# 14            0.000276       3619.232323  13738260      2006           781
# ...                ...               ...       ...       ...           ...
# 2539          0.000019      52731.400000   1521942      2017           256
# 2541          0.000018      54732.583333  17956802      2017           378
# 2542          0.000006     180696.000000   1696093      2017           181
# 2545          0.000038      26495.882353   9144016      2017           192
# 2549          0.000020      48965.125000  13100422      2017           142
#
#       funny_count  contain_funny  pct_funny
# 1             544           True   0.185286
# 4            1390           True   0.054254
# 7               9           True   0.008789
# 11              5           True   0.008446
# 14             14           True   0.017926
# ...           ...            ...        ...
# 2539            2           True   0.007812
# 2541           39           True   0.103175
# 2542            6           True   0.033149
# 2545            1           True   0.005208
# 2549            0           True   0.000000
#
# [786 rows x 25 columns]

# %% [markdown]
# ##### Let's re-do the previous groupby

# %%
(
    filtered_df
    .groupby('speaker_occupation')
    .agg(
        count = ('speaker_occupation', 'count'), 
        mean = ('pct_funny', 'mean')
    )
)
# Out:
#                     count      mean
# speaker_occupation
# Activist               10  0.012539
# Architect              30  0.030579
# Artist                 34  0.078939
# Astronomer              9  0.044581
# Astrophysicist          7  0.013147
# ...                   ...       ...
# Techno-illusionist      6  0.152171
# Technologist           10  0.050965
# Violinist               5  0.009534
# Writer                 45  0.060745
# Writer, activist        6  0.026665
#
# [68 rows x 2 columns]

# %% [markdown]
# > ### <font color = "blue"> Please consider the following, when using `pandas`: </font>
#
# - Check your assumptions about your data
# - Check whether your results are reasonable
# - Take advantage of the fact that pandas operations often output a DataFrame or a Series
# - Watch out for small sample sizes
# - Consider the impact of missing data
#
# > ### <font color = "blue"> As you could find from me as well as from the dataset, `data scientists are relatively funny` :) </font>

# %% [markdown]
# ### <font color="green">"Thank you for putting your efforts into the exercise problem sets 😊"</font>
